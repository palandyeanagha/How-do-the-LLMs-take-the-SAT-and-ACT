# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
import json
import os, os.path

from collections import defaultdict

import torch
import torch.nn as nn
import transformers
import re

from transformers import (AutoTokenizer,
                          AutoModelForCausalLM)
from peft import (PeftModel,
                  PeftConfig)

import spacy
import random
import copy
import nltk
from nltk.tokenize import sent_tokenize
from shutil import copyfile

import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# put your file path here
path_to_nlu_dir = "/content/drive/MyDrive/NLU/Final Project/NLU_FinalProject/"

data_dir = path_to_nlu_dir+"Data/JSONL_Formatted/"
#data_path = "RACE-H/RACE-H_v1_tst.jsonl"
#data_name = 'RACE-H_FineTuneV1_InfoAlterationSent_test' #InfoAlterationSyn_test'
#data_path = "SAT_ACT/SATACT_v3_tst.jsonl"
#data_name = 'SATACT_FineTuneV1_InfoAlterationSent_test'

save_dir = path_to_nlu_dir+"Results/v2_Results/"

model_name = "gpt2-xl" #baseline
#model_name = "Salm00n/gpt2-xl_RACE-H_v1" #v1 race-h fine-tuned
#model_name = "Salm00n/gpt2-xl_SATACT_v1" #v1 sat/act fine-tuned
BATCH_SIZE = 1

# %%
data_list1 = ["RACE-H/RACE-H_v1_trn.jsonl", "RACE-H/RACE-H_v1_dev.jsonl", "RACE-H/RACE-H_v1_tst.jsonl"]
data_list2 = ["SAT_ACT/SATACT_v3_trn.jsonl", "SAT_ACT/SATACT_v3_dev.jsonl", "SAT_ACT/SATACT_v3_tst.jsonl"]

# %%
def hltag(data):
    U = set(['just', 'being', 'able', 'over', 'mainly', 'still', 'yet', 'seemed', 'whose', 'based', 'also', 'writer', 'had', 'should', 'to', 'sometimesd', 'has', 'might', 'then', 'very', 'ones', 'whether', 'not', 'during', 'now', 'realize', 'did', 'this', 't', 'each', 'where', 'because', 'doing', 'some', 'likely', 'are', 'further', 'really', 'even', 'what', 'said', 'for', 'lots', 'since', 'please', 'does', 'between', 'probably', 'ever', 'either', 'available', 'be', 'recently', 'however', 'here', 'although', 'by', 'both', 'about', 'anything', 'of', 'could', 'title', 'according', 's', 'or', 'among', 'already', 'suddenly', 'seems', 'simply', 'passage', 'from', 'would', 'whom', 'there', 'been', 'few', 'too', 'was', 'until', 'that', 'but', 'else', 'with', 'than', 'those', 'must', 'showed', 'these', 'will', 'while', 'can', 'were', 'following', 'and', 'do', 'almost', 'is', 'it', 'an', 'as', 'at', 'have', 'seem', 'if', 'again', 'author', 'rather', 'when', 'how', 'other', 'which', 'instead', 'several', 'though', 'may', 'who', 'most', 'such', 'why', 'recent', 'a', 'don', 'especially', 'maybe', 'perhaps', 'so', 'the', 'having', 'nearly'])
    nlp = spacy.load('en_core_web_sm')
    salientPosList = ['NN', 'NNP', 'NNPS', 'NNS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'JJ', 'JJR', 'JJS', 'RB',
                      'RBR', 'RBS', 'CD', 'FW']  # 21 core pos tag
    output = []
    for i in range(len(data)):
        if not data[i][0] or not isinstance(data[i][0], list):
            print(data[i])
            continue
        article = ' '.join(data[i][0])
        if not article.strip():
            continue
        #print(article)
        article = nlp(article)

        for j in range(len(data[i][1])):
            d = copy.deepcopy(data[i])
            d[0] = []

            question = data[i][1][j]["question"]
            if not question.strip():
                print(data[i])
                continue
            question = nlp(question)

            for k in range(len(data[i][1][j]["choice"])):
                key = set()
                for token in question:
                    if token.tag_ in salientPosList and token.text.lower() not in U:
                        key.add(token.text.lower())
                choice = data[i][1][j]["choice"][k]
                if not isinstance(choice, str) or not choice.strip():
                    print(data[i])
                    continue
                choice = nlp(choice)

                for token in choice:
                    if token.tag_ in salientPosList:
                        key.add(token.text.lower())
                articleatt = []
                for token in article:
                    if token.tag_ in salientPosList and token.text.lower() in key:
                        articleatt += ['[[HL]]']
                        articleatt += [token.text]
                        articleatt += ['[[/HL]]']
                    else:
                        articleatt += [token.text]
            d[0] += [' '.join(articleatt)]
            #print(d[0])
            d[1] = [data[i][1][j]]
            output.append(d)
    return output

# %%
def preprocess(data_list):
    splits = ["sft_trn", "sft_dev", "sft_tst"]
    for n in range(len(data_list)):
      print("preprocessing:", data_list[n])
      file_path = data_dir + data_list[n]
      output = []
      d1 = splits[n]

      with open(file_path, "r") as f:
        for line in f:
          data = json.loads(line)
          d = [[data["context"]], [], d1]
          q = {
              "question": data["question"],
              "choice": [data["answerA"], data["answerB"], data["answerC"], data["answerD"]],
              "answer": data[f"answer{data['correct']}"]
          }
          d[1].append(q)
          output.append(d)

        print(d1, "before highlighting:", len(output))
        output = hltag(output)
        print(d1, "after highlighting:", len(output))

        with open(file_path + '_' + d1, "w") as f:
            json.dump(output, f, indent=2)

# %%
preprocess(data_list1)
# Out:
# preprocessing: RACE-H/RACE-H_v1_trn.jsonl
# sft_trn before highlighting: 62445
# [['One hundred and thirteen million Americans have at least one bank-issued credit card. They give their owners automatic credit in stores, restaurants, and hotels, at home, across the country, and even abroad, and they make many banking services available as well. More and more of these credit cards can be read automatically, making it possible to withdraw or deposit money in scattered locations, whether or not the local branch bank is open. For many of us the "cashless society" is not on the horizon----it\'s already here.\nWhile computers offer these conveniences to consumers, they have many advantages for sellers too. Electronic cash registers can do much more than simply _ . They can keep a wide range of records, including who sold what, when, and to whom. This information allows businessmen to keep track of their list of goods by showing which items are being sold and how fast they are moving. Decisions to reorder or return goods to suppliers can then be made. At the same time these computers record which hours are busiest and which employees are the most efficient, allowing personnel and staffing assignments to be made accordingly. And they also identify preferred customer for promotional campaigns. Computers are relied on by manufacturers for similar reasons. Computer analyzed marketing reports can help to decide which products to emphasize now, which to develop for the future and which to drop. Computers keep track of goods in stock, of raw materials on hand, and even of the production process itself.\nNumerous other commercial enterprises, from theaters to magazine publishers, from gas and electric utilities to milk processors, bring better and more efficient services to consumers through the use of computers.'], [{'question': 'It can be inferred that  _  .', 'choice': ['computers will bring disaster', 'computer industry will not develop faster', "computers will bring about more convenience to people's life", nan], 'answer': "computers will bring about more convenience to people's life"}], 'sft_trn']
# [['When I met him, I had a lot of anger inside me. I\'ve lived my whole life in Spanish Harlem, but in my neighborhood, there are shoot-ups all the time. I know kids who have been shot or beaten up. I have friends who ended up in prison. I could have ended up that way, too, but Mr. Clark wouldn\'t let that happen.\nMr. Clark worked long hours, making sure I did my work. My grades rose. In fact, the scores of our whole class rose. One day, he took our class to see The Phantom of the Opera, and it was the first time some kids had ever been out of Harlem. Before the show, he treated us to dinner at a restaurant and taught us not to talk with our mouths full. We did not want to let him down.\nMr. Clark was selected as Disney\'s 2000 Teacher of the Year. He said he would draw three names out of a hat  ; those students would go with him to Los Angles to get the award. But when the time came to draw names, Mr. Clark said, "You\'re all going."\nOn graduation day, there were a lot of tears. We didn\'t want his class to end. In 2001, he moved to Atlanta, but he always kept in touch. He started giving lectures about education, and wrote a best-selling book based on his classroom rules, The Essential 55. In 2003, Mr. Clark took some of us on a trip to South Africa to deliver school supplies and visit orphanages  . It was the most amazing experience of my life. It\'s now my dream to start a group of women\'s clubs one day, helping people from all backgrounds.'], [{'question': "How many students' names were finally drawn out of a hat by Mr. Clark?", 'choice': [nan, 'Three', 'Fifty-five', 'All'], 'answer': nan}], 'sft_trn']
# [['On this vivid planet, it appears color1ful with many world famous buildings. Among these largest artificial articles in the world, many were designed by the same architect--Ieoh Ming Pei.\nPei, the 1983 Laureate of the Pritzker, Architecture Prize, is a founding partner of I. M. Pei & Partners based in New York City. He was born in China in 1917, the son of a banker. He came to the United States in 1935 to study architecture at the Massachusetts Institute of Technology and the Harvard Graduate School of Design (M. Arch. 1946).\nFrom 1945 to 1948, Pei taught at Harvard. In 1948 he accepted the newly created post of director of Architecture at Webb & Knapp, Inc., and this association resulted in major architectural and planning projects in big cities. In 1958, he formed the partnership of I. M. Pei & Associates, which became I. M. Pei & Partners in 1966. The partnership received the 1968 Architectural Firm Award of The American Institute of Architects.\nPei has designed over forty projects in the world, twenty of which have been award winners. His outstanding projects have included the East Building of the National Gallery of Art, Washington, D.C.; the John Fitzgerald Kennedy Library near Boston; the Fragrant Hill Hotel near Beijing, China.\nPei is now a member of the National Council on the Arts, and before served on the National Council on the Humanities. He is a Fellow of the American Institute of Architects, a member of the Royal Institute of British Architects, and an elected member of the American Academy of Arts and Letters. He is a member of the Corporation of the Massachusetts Institute of Technology.\nAs a student, he was awarded the MIT Traveling Fellowship, at Harvard. He later won a lot of honors. In 1982, the deans of the architectural schools of America chose I. M. Pei as the best designer of significant non-residential   structures.'], [{'question': "_   of Pei's structures have won awards.", 'choice': ['More than forty', 'Over twenty', nan, 'Twenty'], 'answer': 'Twenty'}], 'sft_trn']
# [['There is a nine-year-old kid sitting at his desk and all of a sudden, there is water between his feet and his pants are wet. He thinks his heart is going to stop. It\'s never happened before, and he knows that when the boys find out he will never hear the end of it. When the girls find out, they\'ll never speak to him again .\nThe boy puts his head down and prays, "Dear God, this is an emergency! I need help now! I\'m dead meat ."He looks up from his prayer and here comes the teacher with a look in her eyes that says he has been discovered.\nAs the teacher is walking toward him, a classmate named Susie is carrying a goldfish bowl that is filled with water. Susie trips  in front of the teacher and throws the bowl of water on the boy\'s legs.\nThe boy pretends to be angry, but all the while is saying to himself, "Thank you, Lord! Thank you, Lord!"\nNow all of a sudden, instead of being the object of  _ , the boy is the object of sympathy. The teacher gives him gym shorts to put on while his pants are dried out. All the other children are on their hands and knees cleaning up around his desk. The sympathy is wonderful. But as life would have it, the ridicule that should have been his goes to someone else - Susie. She tries to help, but they tell her to get out. You\'ve done enough, you klutz!\'\nFinally, at the end of the day, as they are waiting for the bus, the boy walks over to Susie and whispers, \'You did that on purpose, didn\'t you?\'  Susie whispers back, \'I wet my pants once too.\''], [{'question': 'How many people in the story know the truth about the wet pants?', 'choice': [nan, 'Two', 'Three', 'Four'], 'answer': 'Three'}], 'sft_trn']
# [['Ever since he got into the Hong Kong film industry in 1994 with He\'s a Woman, She\'s a Man, Hong Kong director, Peter Chan has been one of the industry\'s most powerful voices. Later in 1996, another milestone Comrades: Almost a Love Story came into being. Chan\'s latest film, American Dreams in China is a carefully-calculated film with an eye toward opening the mainland cinema market.\nAmerican Dreams in China is a film purely for Chinese audiences, but how it plays there remains to be seen. It sends the right messages, but whether that\'s enough to make it a hit is everyone\'s guess. Mainland audiences aren\'t quite that easy to "speak" to.\nThe film began during the period of economic reforms in China in the 1980s. The bookish farm boy Cheng Dongqing (Huang Xiaoming), the ambitious and confident boy Meng Xiaojun (Deng Chao) and the poetic Wang Yang(Tong Dawei), were three friends at university in Beijing and preparing for American visa interviews. Wang was the first to be _ the visa but he gave it up for his western girlfriend, and Cheng was repeatedly denied. Only Meng actually got a study visa. As he was leaving, he told his friends that he wouldn\'t come back.\nSeveral years later, Cheng and Wang built a successful school, New Dream, from the ashes of Cheng\'s misfortune(his girlfriend got a visa too, and Cheng lost his university teaching job) and Wang\'s ability to connect with students often through Hollywood movies. In America, Meng suffered a lot. Disappointed, he went home and joined his friends at New Dream. Later, the three friends\' relationship became worsened, but finally was improved under the weight of their common goals.'], [{'question': 'When the three men made preparations for American visa interviews, how many was/were offered a visa?', 'choice': [nan, 'One.', 'Three.', 'Two'], 'answer': 'Two'}], 'sft_trn']
# sft_trn after highlighting: 62445
# preprocessing: RACE-H/RACE-H_v1_dev.jsonl
# sft_dev before highlighting: 3451
# sft_dev after highlighting: 3451
# preprocessing: RACE-H/RACE-H_v1_tst.jsonl
# sft_tst before highlighting: 3498
# sft_tst after highlighting: 3498

# %%
preprocess(data_list2)
# Out:
# preprocessing: SAT_ACT/SATACT_v3_trn.jsonl
# sft_trn before highlighting: 919
# [['Many of William Shakespeare’s tragedies address broad themes that still appeal to today’s audiences. For instance, Romeo and Juliet, which is set in the Italy of Shakespeare’s time, tackles the themes of parents versus children and love versus hate, and the play continues to be read and produced widely around the world. But understanding Shakespeare’s so-called history plays can require a knowledge of several centuries of English history. Consequently,   _  '], [{'question': 'many theatergoers and readers today are likely to find Shakespeare’s history plays less engaging than the tragedies.', 'choice': ['some of Shakespeare’s tragedies are more relevant to today’s audiences than twentieth-century plays.', 'Romeo and Juliet is the most thematically accessible of all Shakespeare’s tragedies.', 'experts in English history tend to prefer Shakespeare’s history plays to his other works.', None], 'answer': 'some of Shakespeare’s tragedies are more relevant to today’s audiences than twentieth-century plays.'}], 'sft_trn']
# sft_trn after highlighting: 919
# preprocessing: SAT_ACT/SATACT_v3_dev.jsonl
# sft_dev before highlighting: 131
# sft_dev after highlighting: 131
# preprocessing: SAT_ACT/SATACT_v3_tst.jsonl
# sft_tst before highlighting: 264
# sft_tst after highlighting: 264

# %%
def read_contexts(split):
  contexts = []
  with open(data_dir + split, "r") as f:
    for line in f:
      obj = json.loads(line)
      contexts.append(obj["context"])
  return contexts

# %%
def problem_gen(article, id):
    delimiter = '_[[#@]]_'

    def get_cloze(sentence, words):
        cloze = []
        ans = []
        dis = []
        sentences = sentence.split(delimiter)
        tokens = []

        for i, sent in enumerate(sentences):
            tokens += nltk.word_tokenize(sent)
            if i != len(sentences) - 1:
                tokens.append(delimiter)

        if len(tokens) > 50:
            return None

        used = set()
        n_cloze = min((len(tokens)-2) // 6, 4)

        if len(tokens) >= 6 and n_cloze <= 0:
            if len(tokens) >= 6:
                n_cloze = 1

        if n_cloze <= 0:
            return None

        n_cloze = random.randint(1, n_cloze)

        for _ in range(n_cloze):
            while True:
                cloze_len = random.randint(1, 4)
                left = random.randint(0, len(tokens)-cloze_len)

                if any(j in used for j in range(left, left + cloze_len)):
                  continue

                if not all(tokens[j].isalpha() for j in range(left, left + cloze_len)):
                  continue

                for j in range(left, left + cloze_len):
                  used.add(j)

                cloze.append([left, left + cloze_len])
                ans.append(' '.join(tokens[left:left + cloze_len]))
                break

        if not ans:
            return None

        for a in ans:
            dislen = max(1, random.randint(len(a.split()) - 1, len(a.split()) + 1))
            dislis = []
            for _ in range(3):
                while True:
                    start = random.randint(0, len(words)-dislen)
                    d = ' '.join(words[start:start+dislen])
                    if d != a and d not in dislis:
                        dislis.append(d)
                        break

            dis.append(dislis)

        for left, right in cloze:
            for j in range(left, right):
                tokens[j] = ''
            tokens[left] = '_'

        ret = [' '.join(' '.join(tokens).split()), ', '.join(ans)]
        for i in range(3):
            ret.append(', '.join(dis[i] for dis in dis))

        return ret

    d = [[], [], id]
    article = article.replace(delimiter, '')
    sentences_raw = sent_tokenize(article)
    sentences = [[s, idx] for idx, s in enumerate(sentences_raw)]
    words = [x for x in nltk.word_tokenize(article) if x.isalpha()]

    n_problem = min(10, len(words) // 30)
    for _ in tqdm(range(n_problem), desc=f"Generating problems for {id}"):
        random.shuffle(sentences)
        selected = [s[0] for s in sentences[:random.randint(1, 3)]]
        question = get_cloze(delimiter.join(selected), words)

        if question is not None:
            q = {"question": ' '.join(question[0].replace(delimiter, '').split()), "choice": question[1:]}
            if any(existing["question"] == q["question"] for existing in d[1]):
                continue

            if len(set(q["choice"])) != 4:
                continue

            random.shuffle(q["choice"])
            q["answer"] = question[1]
            d[1].append(q)

    sentences.sort(key = lambda x : x[1])
    d[0].append(' '.join([s[0] for s in sentences]))
    return d

# %%
cloze_data1 = ["RACE-H/RACE-H_v1_trn.jsonl"]
cloze_split = ["sftc_trn"]
#cloze_data1 = ["RACE-H/RACE-H_v1_dev.jsonl"]
#cloze_split = ["sftc_dev"]

for n in range(len(cloze_data1)):
  fn = cloze_split[n]
  dn = cloze_data1[n]
  output = []
  data = read_contexts(dn)
  #data = data[:357] #skip idx 357
  #data = data[358:2284] #skip idx 2284
  #data = data[2285:5000]
  #data = data[20000:25000]
  #data = data[30000:34217] #skip idx 34217
  #data = data[34218:35000]
  #data = data[50000:51215] #skip idx 51215
  #data = data[51216:53148] #skip idx 53148-53150
  data = data[53151:55000]

  for i, context in enumerate(data):
    output.append(problem_gen(context, str(i)))

  print(fn, "generated:", len(output), "total questions:", sum(len(item[1]) for item in output))
  output = hltag(output)

  print(fn, "after highlighting:", len(output))

  with open(data_dir + dn + '_' + fn + '_53151-55000', "w") as f:
    json.dump(output, f, indent=2)
# Out:
# Generating problems for 0: 100%|██████████| 10/10 [00:00<00:00, 1812.42it/s]
# Generating problems for 1: 100%|██████████| 10/10 [00:00<00:00, 2074.74it/s]
# Generating problems for 2: 100%|██████████| 10/10 [00:00<00:00, 1195.23it/s]
# Generating problems for 3: 100%|██████████| 10/10 [00:00<00:00, 1627.02it/s]
# Generating problems for 4: 100%|██████████| 10/10 [00:00<00:00, 1129.35it/s]
# Generating problems for 5: 100%|██████████| 10/10 [00:00<00:00, 1251.28it/s]
# Generating problems for 6: 100%|██████████| 10/10 [00:00<00:00, 1767.44it/s]
# Generating problems for 7: 100%|██████████| 10/10 [00:00<00:00, 1839.61it/s]
# Generating problems for 8: 100%|██████████| 10/10 [00:00<00:00, 1342.69it/s]
# Generating problems for 9: 100%|██████████| 10/10 [00:00<00:00, 1649.35it/s]
# Generating problems for 10: 100%|██████████| 10/10 [00:00<00:00, 1330.81it/s]
# Generating problems for 11: 100%|██████████| 9/9 [00:00<00:00, 1809.97it/s]
# Generating problems for 12: 100%|██████████| 9/9 [00:00<00:00, 1581.03it/s]
# Generating problems for 13: 100%|██████████| 9/9 [00:00<00:00, 1605.78it/s]
# Generating problems for 14: 100%|██████████| 10/10 [00:00<00:00, 1545.72it/s]
# Generating problems for 15: 100%|██████████| 10/10 [00:00<00:00, 1538.18it/s]
# Generating problems for 16: 100%|██████████| 10/10 [00:00<00:00, 1562.07it/s]
# Generating problems for 17: 100%|██████████| 8/8 [00:00<00:00, 1316.94it/s]
# Generating problems for 18: 100%|██████████| 8/8 [00:00<00:00, 1336.56it/s]
# Generating problems for 19: 100%|██████████| 8/8 [00:00<00:00, 1465.39it/s]
# Generating problems for 20: 100%|██████████| 10/10 [00:00<00:00, 2263.40it/s]
# Generating problems for 21: 100%|██████████| 10/10 [00:00<00:00, 2360.46it/s]
# Generating problems for 22: 100%|██████████| 10/10 [00:00<00:00, 2061.69it/s]
# Generating problems for 23: 100%|██████████| 9/9 [00:00<00:00, 1787.43it/s]
# Generating problems for 24: 100%|██████████| 9/9 [00:00<00:00, 2448.20it/s]
# Generating problems for 25: 100%|██████████| 9/9 [00:00<00:00, 2286.55it/s]
# Generating problems for 26: 100%|██████████| 6/6 [00:00<00:00, 1554.89it/s]
# Generating problems for 27: 100%|██████████| 6/6 [00:00<00:00, 1371.73it/s]
# Generating problems for 28: 100%|██████████| 6/6 [00:00<00:00, 744.73it/s]
# Generating problems for 29: 100%|██████████| 8/8 [00:00<00:00, 1746.35it/s]
# Generating problems for 30: 100%|██████████| 8/8 [00:00<00:00, 1229.37it/s]
# Generating problems for 31: 100%|██████████| 8/8 [00:00<00:00, 1308.88it/s]
# Generating problems for 32: 100%|██████████| 9/9 [00:00<00:00, 815.59it/s]
# Generating problems for 33: 100%|██████████| 9/9 [00:00<00:00, 772.04it/s]
# Generating problems for 34: 100%|██████████| 9/9 [00:00<00:00, 1542.59it/s]
# Generating problems for 35: 100%|██████████| 9/9 [00:00<00:00, 971.68it/s]
# Generating problems for 36: 100%|██████████| 10/10 [00:00<00:00, 1498.45it/s]
# Generating problems for 37: 100%|██████████| 10/10 [00:00<00:00, 1636.48it/s]
# Generating problems for 38: 100%|██████████| 10/10 [00:00<00:00, 1849.01it/s]
# Generating problems for 39: 100%|██████████| 10/10 [00:00<00:00, 2377.45it/s]
# Generating problems for 40: 100%|██████████| 10/10 [00:00<00:00, 2165.70it/s]
# Generating problems for 41: 100%|██████████| 6/6 [00:00<00:00, 1465.94it/s]
# Generating problems for 42: 100%|██████████| 6/6 [00:00<00:00, 1613.30it/s]
# Generating problems for 43: 100%|██████████| 6/6 [00:00<00:00, 1253.22it/s]
# Generating problems for 44: 100%|██████████| 6/6 [00:00<00:00, 999.44it/s]
# Generating problems for 45: 100%|██████████| 10/10 [00:00<00:00, 1942.98it/s]
# Generating problems for 46: 100%|██████████| 10/10 [00:00<00:00, 1854.98it/s]
# Generating problems for 47: 100%|██████████| 10/10 [00:00<00:00, 1164.05it/s]
# Generating problems for 48: 100%|██████████| 10/10 [00:00<00:00, 1815.40it/s]
# Generating problems for 49: 100%|██████████| 10/10 [00:00<00:00, 1598.80it/s]
# Generating problems for 50: 100%|██████████| 10/10 [00:00<00:00, 1146.64it/s]
# Generating problems for 51: 100%|██████████| 10/10 [00:00<00:00, 1655.47it/s]
# Generating problems for 52: 100%|██████████| 8/8 [00:00<00:00, 1461.94it/s]
# Generating problems for 53: 100%|██████████| 8/8 [00:00<00:00, 1746.44it/s]
# Generating problems for 54: 100%|██████████| 8/8 [00:00<00:00, 1659.39it/s]
# Generating problems for 55: 100%|██████████| 6/6 [00:00<00:00, 1908.82it/s]
# Generating problems for 56: 100%|██████████| 6/6 [00:00<00:00, 1864.41it/s]
# Generating problems for 57: 100%|██████████| 6/6 [00:00<00:00, 1963.47it/s]
# Generating problems for 58: 100%|██████████| 6/6 [00:00<00:00, 2503.56it/s]
# Generating problems for 59: 100%|██████████| 9/9 [00:00<00:00, 2308.51it/s]
# Generating problems for 60: 100%|██████████| 9/9 [00:00<00:00, 2674.94it/s]
# Generating problems for 61: 100%|██████████| 9/9 [00:00<00:00, 2256.48it/s]
# Generating problems for 62: 100%|██████████| 9/9 [00:00<00:00, 1811.45it/s]
# Generating problems for 63: 100%|██████████| 9/9 [00:00<00:00, 1157.62it/s]
# Generating problems for 64: 100%|██████████| 9/9 [00:00<00:00, 1856.34it/s]
# Generating problems for 65: 100%|██████████| 9/9 [00:00<00:00, 1963.32it/s]
# Generating problems for 66: 100%|██████████| 10/10 [00:00<00:00, 1300.76it/s]
# Generating problems for 67: 100%|██████████| 10/10 [00:00<00:00, 1549.77it/s]
# Generating problems for 68: 100%|██████████| 10/10 [00:00<00:00, 1113.46it/s]
# Generating problems for 69: 100%|██████████| 10/10 [00:00<00:00, 1903.82it/s]
# Generating problems for 70: 100%|██████████| 10/10 [00:00<00:00, 1967.22it/s]
# Generating problems for 71: 100%|██████████| 10/10 [00:00<00:00, 1902.61it/s]
# Generating problems for 72: 100%|██████████| 10/10 [00:00<00:00, 2032.52it/s]
# Generating problems for 73: 100%|██████████| 10/10 [00:00<00:00, 1554.71it/s]
# Generating problems for 74: 100%|██████████| 10/10 [00:00<00:00, 1177.94it/s]
# Generating problems for 75: 100%|██████████| 10/10 [00:00<00:00, 1524.65it/s]
# Generating problems for 76: 100%|██████████| 10/10 [00:00<00:00, 2157.79it/s]
# Generating problems for 77: 100%|██████████| 10/10 [00:00<00:00, 1672.30it/s]
# Generating problems for 78: 100%|██████████| 10/10 [00:00<00:00, 926.22it/s]
# Generating problems for 79: 100%|██████████| 10/10 [00:00<00:00, 786.01it/s]
# Generating problems for 80: 100%|██████████| 10/10 [00:00<00:00, 1086.58it/s]
# Generating problems for 81: 100%|██████████| 10/10 [00:00<00:00, 924.20it/s]
# Generating problems for 82: 100%|██████████| 9/9 [00:00<00:00, 1138.86it/s]
# Generating problems for 83: 100%|██████████| 9/9 [00:00<00:00, 1561.03it/s]
# Generating problems for 84: 100%|██████████| 9/9 [00:00<00:00, 1137.22it/s]
# Generating problems for 85: 100%|██████████| 8/8 [00:00<00:00, 2116.20it/s]
# Generating problems for 86: 100%|██████████| 8/8 [00:00<00:00, 1977.63it/s]
# Generating problems for 87: 100%|██████████| 8/8 [00:00<00:00, 1867.25it/s]
# Generating problems for 88: 100%|██████████| 8/8 [00:00<00:00, 1030.64it/s]
# Generating problems for 89: 100%|██████████| 8/8 [00:00<00:00, 963.18it/s]
# Generating problems for 90: 100%|██████████| 7/7 [00:00<00:00, 921.97it/s]
# Generating problems for 91: 100%|██████████| 7/7 [00:00<00:00, 1054.00it/s]
# Generating problems for 92: 100%|██████████| 10/10 [00:00<00:00, 1949.21it/s]
# Generating problems for 93: 100%|██████████| 10/10 [00:00<00:00, 1932.32it/s]
# Generating problems for 94: 100%|██████████| 10/10 [00:00<00:00, 1267.58it/s]
# Generating problems for 95: 100%|██████████| 7/7 [00:00<00:00, 1429.41it/s]
# Generating problems for 96: 100%|██████████| 7/7 [00:00<00:00, 1628.22it/s]
# Generating problems for 97: 100%|██████████| 7/7 [00:00<00:00, 1255.24it/s]
# Generating problems for 98: 100%|██████████| 7/7 [00:00<00:00, 865.06it/s]
# Generating problems for 99: 100%|██████████| 7/7 [00:00<00:00, 829.92it/s]
# Generating problems for 100: 100%|██████████| 10/10 [00:00<00:00, 1267.66it/s]
# Generating problems for 101: 100%|██████████| 10/10 [00:00<00:00, 1295.54it/s]
# Generating problems for 102: 100%|██████████| 10/10 [00:00<00:00, 2022.62it/s]
# Generating problems for 103: 100%|██████████| 10/10 [00:00<00:00, 733.19it/s]
# Generating problems for 104: 100%|██████████| 8/8 [00:00<00:00, 1088.12it/s]
# Generating problems for 105: 100%|██████████| 8/8 [00:00<00:00, 1181.74it/s]
# Generating problems for 106: 100%|██████████| 8/8 [00:00<00:00, 1035.18it/s]
# Generating problems for 107: 100%|██████████| 8/8 [00:00<00:00, 1497.43it/s]
# Generating problems for 108: 100%|██████████| 10/10 [00:00<00:00, 1722.93it/s]
# Generating problems for 109: 100%|██████████| 10/10 [00:00<00:00, 1552.12it/s]
# Generating problems for 110: 100%|██████████| 10/10 [00:00<00:00, 1304.04it/s]
# Generating problems for 111: 100%|██████████| 9/9 [00:00<00:00, 2605.70it/s]
# Generating problems for 112: 100%|██████████| 9/9 [00:00<00:00, 2027.21it/s]
# Generating problems for 113: 100%|██████████| 9/9 [00:00<00:00, 2640.88it/s]
# Generating problems for 114: 100%|██████████| 9/9 [00:00<00:00, 1979.07it/s]
# Generating problems for 115: 100%|██████████| 10/10 [00:00<00:00, 2278.89it/s]
# Generating problems for 116: 100%|██████████| 10/10 [00:00<00:00, 2309.77it/s]
# Generating problems for 117: 100%|██████████| 10/10 [00:00<00:00, 2183.28it/s]
# Generating problems for 118: 100%|██████████| 10/10 [00:00<00:00, 2473.93it/s]
# Generating problems for 119: 100%|██████████| 6/6 [00:00<00:00, 3095.43it/s]
# Generating problems for 120: 100%|██████████| 6/6 [00:00<00:00, 2284.06it/s]
# Generating problems for 121: 100%|██████████| 9/9 [00:00<00:00, 2688.27it/s]
# Generating problems for 122: 100%|██████████| 9/9 [00:00<00:00, 3080.77it/s]
# Generating problems for 123: 100%|██████████| 9/9 [00:00<00:00, 2606.96it/s]
# Generating problems for 124: 100%|██████████| 10/10 [00:00<00:00, 2509.01it/s]
# Generating problems for 125: 100%|██████████| 10/10 [00:00<00:00, 2203.35it/s]
# Generating problems for 126: 100%|██████████| 10/10 [00:00<00:00, 2168.38it/s]
# Generating problems for 127: 100%|██████████| 10/10 [00:00<00:00, 2283.24it/s]
# Generating problems for 128: 100%|██████████| 9/9 [00:00<00:00, 3850.34it/s]
# Generating problems for 129: 100%|██████████| 9/9 [00:00<00:00, 2345.08it/s]
# Generating problems for 130: 100%|██████████| 10/10 [00:00<00:00, 2214.29it/s]
# Generating problems for 131: 100%|██████████| 10/10 [00:00<00:00, 1834.62it/s]
# Generating problems for 132: 100%|██████████| 10/10 [00:00<00:00, 2445.66it/s]
# Generating problems for 133: 100%|██████████| 10/10 [00:00<00:00, 2560.31it/s]
# Generating problems for 134: 100%|██████████| 10/10 [00:00<00:00, 1941.27it/s]
# Generating problems for 135: 100%|██████████| 10/10 [00:00<00:00, 2064.63it/s]
# Generating problems for 136: 100%|██████████| 10/10 [00:00<00:00, 2458.99it/s]
# Generating problems for 137: 100%|██████████| 10/10 [00:00<00:00, 1972.77it/s]
# Generating problems for 138: 100%|██████████| 10/10 [00:00<00:00, 1938.40it/s]
# Generating problems for 139: 100%|██████████| 10/10 [00:00<00:00, 2342.01it/s]
# Generating problems for 140: 100%|██████████| 10/10 [00:00<00:00, 2305.32it/s]
# Generating problems for 141: 100%|██████████| 10/10 [00:00<00:00, 1842.44it/s]
# Generating problems for 142: 100%|██████████| 10/10 [00:00<00:00, 1956.21it/s]
# Generating problems for 143: 100%|██████████| 6/6 [00:00<00:00, 2226.87it/s]
# Generating problems for 144: 100%|██████████| 6/6 [00:00<00:00, 2923.88it/s]
# Generating problems for 145: 100%|██████████| 6/6 [00:00<00:00, 2612.73it/s]
# Generating problems for 146: 100%|██████████| 6/6 [00:00<00:00, 1960.72it/s]
# Generating problems for 147: 100%|██████████| 8/8 [00:00<00:00, 2192.96it/s]
# Generating problems for 148: 100%|██████████| 8/8 [00:00<00:00, 2296.99it/s]
# Generating problems for 149: 100%|██████████| 8/8 [00:00<00:00, 1953.11it/s]
# Generating problems for 150: 100%|██████████| 8/8 [00:00<00:00, 1989.94it/s]
# Generating problems for 151: 100%|██████████| 8/8 [00:00<00:00, 1702.32it/s]
# Generating problems for 152: 100%|██████████| 8/8 [00:00<00:00, 1610.33it/s]
# Generating problems for 153: 100%|██████████| 8/8 [00:00<00:00, 1592.14it/s]
# Generating problems for 154: 100%|██████████| 8/8 [00:00<00:00, 1800.90it/s]
# Generating problems for 155: 100%|██████████| 10/10 [00:00<00:00, 2585.88it/s]
# Generating problems for 156: 100%|██████████| 10/10 [00:00<00:00, 1989.99it/s]
# Generating problems for 157: 100%|██████████| 7/7 [00:00<00:00, 2048.00it/s]
# Generating problems for 158: 100%|██████████| 7/7 [00:00<00:00, 2142.14it/s]
# Generating problems for 159: 100%|██████████| 7/7 [00:00<00:00, 2620.74it/s]
# Generating problems for 160: 100%|██████████| 7/7 [00:00<00:00, 2734.74it/s]
# Generating problems for 161: 100%|██████████| 10/10 [00:00<00:00, 2231.25it/s]
# Generating problems for 162: 100%|██████████| 10/10 [00:00<00:00, 2829.78it/s]
# Generating problems for 163: 100%|██████████| 6/6 [00:00<00:00, 1834.38it/s]
# Generating problems for 164: 100%|██████████| 6/6 [00:00<00:00, 2231.41it/s]
# Generating problems for 165: 100%|██████████| 6/6 [00:00<00:00, 2478.90it/s]
# Generating problems for 166: 100%|██████████| 6/6 [00:00<00:00, 1674.37it/s]
# Generating problems for 167: 100%|██████████| 6/6 [00:00<00:00, 1516.47it/s]
# Generating problems for 168: 100%|██████████| 6/6 [00:00<00:00, 1816.37it/s]
# Generating problems for 169: 100%|██████████| 4/4 [00:00<00:00, 1699.82it/s]
# Generating problems for 170: 100%|██████████| 4/4 [00:00<00:00, 1646.44it/s]
# Generating problems for 171: 100%|██████████| 4/4 [00:00<00:00, 1802.06it/s]
# Generating problems for 172: 100%|██████████| 4/4 [00:00<00:00, 1808.67it/s]
# Generating problems for 173: 100%|██████████| 4/4 [00:00<00:00, 2191.67it/s]
# Generating problems for 174: 100%|██████████| 8/8 [00:00<00:00, 1545.72it/s]
# Generating problems for 175: 100%|██████████| 8/8 [00:00<00:00, 1907.04it/s]
# Generating problems for 176: 100%|██████████| 8/8 [00:00<00:00, 1840.72it/s]
# Generating problems for 177: 100%|██████████| 8/8 [00:00<00:00, 2229.38it/s]
# Generating problems for 178: 100%|██████████| 10/10 [00:00<00:00, 2220.62it/s]
# Generating problems for 179: 100%|██████████| 10/10 [00:00<00:00, 2142.36it/s]
# Generating problems for 180: 100%|██████████| 10/10 [00:00<00:00, 2350.94it/s]
# Generating problems for 181: 100%|██████████| 10/10 [00:00<00:00, 2353.84it/s]
# Generating problems for 182: 100%|██████████| 10/10 [00:00<00:00, 1791.14it/s]
# Generating problems for 183: 100%|██████████| 10/10 [00:00<00:00, 2317.81it/s]
# Generating problems for 184: 100%|██████████| 10/10 [00:00<00:00, 1966.94it/s]
# Generating problems for 185: 100%|██████████| 10/10 [00:00<00:00, 2277.16it/s]
# Generating problems for 186: 100%|██████████| 10/10 [00:00<00:00, 2093.17it/s]
# Generating problems for 187: 100%|██████████| 10/10 [00:00<00:00, 2088.80it/s]
# Generating problems for 188: 100%|██████████| 10/10 [00:00<00:00, 2210.55it/s]
# Generating problems for 189: 100%|██████████| 9/9 [00:00<00:00, 2445.18it/s]
# Generating problems for 190: 100%|██████████| 9/9 [00:00<00:00, 2456.48it/s]
# Generating problems for 191: 100%|██████████| 9/9 [00:00<00:00, 2256.89it/s]
# Generating problems for 192: 100%|██████████| 10/10 [00:00<00:00, 2131.79it/s]
# Generating problems for 193: 100%|██████████| 10/10 [00:00<00:00, 1835.66it/s]
# Generating problems for 194: 100%|██████████| 10/10 [00:00<00:00, 1750.03it/s]
# Generating problems for 195: 100%|██████████| 10/10 [00:00<00:00, 1666.06it/s]
# Generating problems for 196: 100%|██████████| 10/10 [00:00<00:00, 1478.06it/s]
# Generating problems for 197: 100%|██████████| 10/10 [00:00<00:00, 1981.16it/s]
# Generating problems for 198: 100%|██████████| 10/10 [00:00<00:00, 1561.31it/s]
# Generating problems for 199: 100%|██████████| 10/10 [00:00<00:00, 2254.15it/s]
# Generating problems for 200: 100%|██████████| 10/10 [00:00<00:00, 1636.10it/s]
# Generating problems for 201: 100%|██████████| 10/10 [00:00<00:00, 1954.66it/s]
# Generating problems for 202: 100%|██████████| 10/10 [00:00<00:00, 1903.30it/s]
# Generating problems for 203: 100%|██████████| 8/8 [00:00<00:00, 1241.56it/s]
# Generating problems for 204: 100%|██████████| 8/8 [00:00<00:00, 1342.93it/s]
# Generating problems for 205: 100%|██████████| 8/8 [00:00<00:00, 1342.39it/s]
# Generating problems for 206: 100%|██████████| 10/10 [00:00<00:00, 2203.12it/s]
# Generating problems for 207: 100%|██████████| 10/10 [00:00<00:00, 1826.63it/s]
# Generating problems for 208: 100%|██████████| 10/10 [00:00<00:00, 1956.75it/s]
# Generating problems for 209: 100%|██████████| 10/10 [00:00<00:00, 1710.08it/s]
# Generating problems for 210: 100%|██████████| 10/10 [00:00<00:00, 1783.07it/s]
# Generating problems for 211: 100%|██████████| 10/10 [00:00<00:00, 1925.05it/s]
# Generating problems for 212: 100%|██████████| 10/10 [00:00<00:00, 1951.29it/s]
# Generating problems for 213: 100%|██████████| 10/10 [00:00<00:00, 1924.61it/s]
# Generating problems for 214: 100%|██████████| 9/9 [00:00<00:00, 1763.30it/s]
# Generating problems for 215: 100%|██████████| 9/9 [00:00<00:00, 2196.10it/s]
# Generating problems for 216: 100%|██████████| 9/9 [00:00<00:00, 2029.17it/s]
# Generating problems for 217: 100%|██████████| 10/10 [00:00<00:00, 1946.67it/s]
# Generating problems for 218: 100%|██████████| 10/10 [00:00<00:00, 2159.01it/s]
# Generating problems for 219: 100%|██████████| 10/10 [00:00<00:00, 1921.61it/s]
# Generating problems for 220: 100%|██████████| 10/10 [00:00<00:00, 2106.42it/s]
# Generating problems for 221: 100%|██████████| 5/5 [00:00<00:00, 3238.84it/s]
# Generating problems for 222: 100%|██████████| 5/5 [00:00<00:00, 3191.04it/s]
# Generating problems for 223: 100%|██████████| 5/5 [00:00<00:00, 2225.09it/s]
# Generating problems for 224: 100%|██████████| 5/5 [00:00<00:00, 2455.39it/s]
# Generating problems for 225: 100%|██████████| 5/5 [00:00<00:00, 2492.75it/s]
# Generating problems for 226: 100%|██████████| 6/6 [00:00<00:00, 2602.19it/s]
# Generating problems for 227: 100%|██████████| 6/6 [00:00<00:00, 2101.18it/s]
# Generating problems for 228: 100%|██████████| 6/6 [00:00<00:00, 2320.71it/s]
# Generating problems for 229: 100%|██████████| 6/6 [00:00<00:00, 2732.74it/s]
# Generating problems for 230: 100%|██████████| 9/9 [00:00<00:00, 2502.24it/s]
# Generating problems for 231: 100%|██████████| 9/9 [00:00<00:00, 1688.53it/s]
# Generating problems for 232: 100%|██████████| 9/9 [00:00<00:00, 1578.65it/s]
# Generating problems for 233: 100%|██████████| 9/9 [00:00<00:00, 2034.31it/s]
# Generating problems for 234: 100%|██████████| 10/10 [00:00<00:00, 1824.96it/s]
# Generating problems for 235: 100%|██████████| 10/10 [00:00<00:00, 1857.37it/s]
# Generating problems for 236: 100%|██████████| 10/10 [00:00<00:00, 1634.00it/s]
# Generating problems for 237: 100%|██████████| 10/10 [00:00<00:00, 1953.38it/s]
# Generating problems for 238: 100%|██████████| 10/10 [00:00<00:00, 1664.27it/s]
# Generating problems for 239: 100%|██████████| 10/10 [00:00<00:00, 2241.86it/s]
# Generating problems for 240: 100%|██████████| 9/9 [00:00<00:00, 2438.08it/s]
# Generating problems for 241: 100%|██████████| 9/9 [00:00<00:00, 2160.77it/s]
# Generating problems for 242: 100%|██████████| 9/9 [00:00<00:00, 1875.62it/s]
# Generating problems for 243: 100%|██████████| 9/9 [00:00<00:00, 2268.96it/s]
# Generating problems for 244: 100%|██████████| 9/9 [00:00<00:00, 2301.19it/s]
# Generating problems for 245: 100%|██████████| 9/9 [00:00<00:00, 2069.56it/s]
# Generating problems for 246: 100%|██████████| 9/9 [00:00<00:00, 1723.37it/s]
# Generating problems for 247: 100%|██████████| 9/9 [00:00<00:00, 1638.26it/s]
# Generating problems for 248: 100%|██████████| 9/9 [00:00<00:00, 2031.47it/s]
# Generating problems for 249: 100%|██████████| 10/10 [00:00<00:00, 1588.09it/s]
# Generating problems for 250: 100%|██████████| 10/10 [00:00<00:00, 1193.67it/s]
# Generating problems for 251: 100%|██████████| 10/10 [00:00<00:00, 2054.12it/s]
# Generating problems for 252: 100%|██████████| 4/4 [00:00<00:00, 2337.31it/s]
# Generating problems for 253: 100%|██████████| 4/4 [00:00<00:00, 1606.09it/s]
# Generating problems for 254: 100%|██████████| 4/4 [00:00<00:00, 2066.41it/s]
# Generating problems for 255: 100%|██████████| 8/8 [00:00<00:00, 1150.98it/s]
# Generating problems for 256: 100%|██████████| 8/8 [00:00<00:00, 1243.13it/s]
# Generating problems for 257: 100%|██████████| 8/8 [00:00<00:00, 1695.18it/s]
# Generating problems for 258: 100%|██████████| 7/7 [00:00<00:00, 1848.76it/s]
# Generating problems for 259: 100%|██████████| 7/7 [00:00<00:00, 1840.41it/s]
# Generating problems for 260: 100%|██████████| 7/7 [00:00<00:00, 2257.78it/s]
# Generating problems for 261: 100%|██████████| 7/7 [00:00<00:00, 1911.22it/s]
# Generating problems for 262: 100%|██████████| 10/10 [00:00<00:00, 1950.75it/s]
# Generating problems for 263: 100%|██████████| 10/10 [00:00<00:00, 1891.88it/s]
# Generating problems for 264: 100%|██████████| 10/10 [00:00<00:00, 2289.09it/s]
# Generating problems for 265: 100%|██████████| 10/10 [00:00<00:00, 2479.78it/s]
# Generating problems for 266: 100%|██████████| 9/9 [00:00<00:00, 2056.03it/s]
# Generating problems for 267: 100%|██████████| 9/9 [00:00<00:00, 2261.08it/s]
# Generating problems for 268: 100%|██████████| 9/9 [00:00<00:00, 2144.45it/s]
# Generating problems for 269: 100%|██████████| 9/9 [00:00<00:00, 1983.96it/s]
# Generating problems for 270: 100%|██████████| 10/10 [00:00<00:00, 1196.77it/s]
# Generating problems for 271: 100%|██████████| 10/10 [00:00<00:00, 2418.86it/s]
# Generating problems for 272: 100%|██████████| 10/10 [00:00<00:00, 1870.29it/s]
# Generating problems for 273: 100%|██████████| 9/9 [00:00<00:00, 2322.43it/s]
# Generating problems for 274: 100%|██████████| 9/9 [00:00<00:00, 2276.08it/s]
# Generating problems for 275: 100%|██████████| 9/9 [00:00<00:00, 2331.32it/s]
# Generating problems for 276: 100%|██████████| 9/9 [00:00<00:00, 2253.66it/s]
# Generating problems for 277: 100%|██████████| 9/9 [00:00<00:00, 2623.81it/s]
# Generating problems for 278: 100%|██████████| 10/10 [00:00<00:00, 2435.72it/s]
# Generating problems for 279: 100%|██████████| 10/10 [00:00<00:00, 1878.24it/s]
# Generating problems for 280: 100%|██████████| 10/10 [00:00<00:00, 2606.94it/s]
# Generating problems for 281: 100%|██████████| 10/10 [00:00<00:00, 2468.25it/s]
# Generating problems for 282: 100%|██████████| 9/9 [00:00<00:00, 2120.60it/s]
# Generating problems for 283: 100%|██████████| 9/9 [00:00<00:00, 1650.87it/s]
# Generating problems for 284: 100%|██████████| 10/10 [00:00<00:00, 1749.30it/s]
# Generating problems for 285: 100%|██████████| 10/10 [00:00<00:00, 2200.23it/s]
# Generating problems for 286: 100%|██████████| 10/10 [00:00<00:00, 2341.22it/s]
# Generating problems for 287: 100%|██████████| 10/10 [00:00<00:00, 2747.12it/s]
# Generating problems for 288: 100%|██████████| 10/10 [00:00<00:00, 2090.57it/s]
# Generating problems for 289: 100%|██████████| 8/8 [00:00<00:00, 2067.18it/s]
# Generating problems for 290: 100%|██████████| 8/8 [00:00<00:00, 2001.22it/s]
# Generating problems for 291: 100%|██████████| 9/9 [00:00<00:00, 2133.54it/s]
# Generating problems for 292: 100%|██████████| 9/9 [00:00<00:00, 2426.32it/s]
# Generating problems for 293: 100%|██████████| 9/9 [00:00<00:00, 1969.26it/s]
# Generating problems for 294: 100%|██████████| 9/9 [00:00<00:00, 2141.89it/s]
# Generating problems for 295: 100%|██████████| 9/9 [00:00<00:00, 1717.65it/s]
# Generating problems for 296: 100%|██████████| 9/9 [00:00<00:00, 1574.50it/s]
# Generating problems for 297: 100%|██████████| 9/9 [00:00<00:00, 1444.43it/s]
# Generating problems for 298: 100%|██████████| 9/9 [00:00<00:00, 2061.08it/s]
# Generating problems for 299: 100%|██████████| 9/9 [00:00<00:00, 2292.39it/s]
# Generating problems for 300: 100%|██████████| 8/8 [00:00<00:00, 1198.29it/s]
# Generating problems for 301: 100%|██████████| 8/8 [00:00<00:00, 1174.26it/s]
# Generating problems for 302: 100%|██████████| 8/8 [00:00<00:00, 2183.25it/s]
# Generating problems for 303: 100%|██████████| 8/8 [00:00<00:00, 1162.78it/s]
# Generating problems for 304: 100%|██████████| 10/10 [00:00<00:00, 1847.47it/s]
# Generating problems for 305: 100%|██████████| 10/10 [00:00<00:00, 2196.55it/s]
# Generating problems for 306: 100%|██████████| 10/10 [00:00<00:00, 1842.03it/s]
# Generating problems for 307: 100%|██████████| 10/10 [00:00<00:00, 2175.36it/s]
# Generating problems for 308: 100%|██████████| 10/10 [00:00<00:00, 2016.40it/s]
# Generating problems for 309: 100%|██████████| 10/10 [00:00<00:00, 1366.67it/s]
# Generating problems for 310: 100%|██████████| 10/10 [00:00<00:00, 1564.11it/s]
# Generating problems for 311: 100%|██████████| 10/10 [00:00<00:00, 1396.61it/s]
# Generating problems for 312: 100%|██████████| 9/9 [00:00<00:00, 1906.89it/s]
# Generating problems for 313: 100%|██████████| 9/9 [00:00<00:00, 1339.18it/s]
# Generating problems for 314: 100%|██████████| 9/9 [00:00<00:00, 1432.97it/s]
# Generating problems for 315: 100%|██████████| 10/10 [00:00<00:00, 554.27it/s]
# Generating problems for 316: 100%|██████████| 10/10 [00:00<00:00, 782.27it/s]
# Generating problems for 317: 100%|██████████| 10/10 [00:00<00:00, 865.73it/s]
# Generating problems for 318: 100%|██████████| 10/10 [00:00<00:00, 919.92it/s]
# Generating problems for 319: 100%|██████████| 9/9 [00:00<00:00, 2136.68it/s]
# Generating problems for 320: 100%|██████████| 9/9 [00:00<00:00, 1881.98it/s]
# Generating problems for 321: 100%|██████████| 8/8 [00:00<00:00, 1510.64it/s]
# Generating problems for 322: 100%|██████████| 8/8 [00:00<00:00, 1549.14it/s]
# Generating problems for 323: 100%|██████████| 8/8 [00:00<00:00, 2075.49it/s]
# Generating problems for 324: 100%|██████████| 8/8 [00:00<00:00, 1560.16it/s]
# Generating problems for 325: 100%|██████████| 9/9 [00:00<00:00, 1761.33it/s]
# Generating problems for 326: 100%|██████████| 9/9 [00:00<00:00, 2059.40it/s]
# Generating problems for 327: 100%|██████████| 7/7 [00:00<00:00, 1729.92it/s]
# Generating problems for 328: 100%|██████████| 7/7 [00:00<00:00, 2350.69it/s]
# Generating problems for 329: 100%|██████████| 7/7 [00:00<00:00, 1718.47it/s]
# Generating problems for 330: 100%|██████████| 8/8 [00:00<00:00, 2597.70it/s]
# Generating problems for 331: 100%|██████████| 8/8 [00:00<00:00, 1069.87it/s]
# Generating problems for 332: 100%|██████████| 8/8 [00:00<00:00, 2606.17it/s]
# Generating problems for 333: 100%|██████████| 6/6 [00:00<00:00, 1029.40it/s]
# Generating problems for 334: 100%|██████████| 6/6 [00:00<00:00, 1114.22it/s]
# Generating problems for 335: 100%|██████████| 6/6 [00:00<00:00, 1240.12it/s]
# Generating problems for 336: 100%|██████████| 10/10 [00:00<00:00, 1822.50it/s]
# Generating problems for 337: 100%|██████████| 10/10 [00:00<00:00, 2283.98it/s]
# Generating problems for 338: 100%|██████████| 10/10 [00:00<00:00, 2576.20it/s]
# Generating problems for 339: 100%|██████████| 10/10 [00:00<00:00, 2140.39it/s]
# Generating problems for 340: 100%|██████████| 10/10 [00:00<00:00, 2027.90it/s]
# Generating problems for 341: 100%|██████████| 9/9 [00:00<00:00, 1435.59it/s]
# Generating problems for 342: 100%|██████████| 9/9 [00:00<00:00, 1029.70it/s]
# Generating problems for 343: 100%|██████████| 9/9 [00:00<00:00, 1730.40it/s]
# Generating problems for 344: 100%|██████████| 9/9 [00:00<00:00, 735.93it/s]
# Generating problems for 345: 100%|██████████| 9/9 [00:00<00:00, 836.17it/s]
# Generating problems for 346: 100%|██████████| 9/9 [00:00<00:00, 853.97it/s]
# Generating problems for 347: 100%|██████████| 10/10 [00:00<00:00, 2262.54it/s]
# Generating problems for 348: 100%|██████████| 10/10 [00:00<00:00, 2278.89it/s]
# Generating problems for 349: 100%|██████████| 10/10 [00:00<00:00, 2394.42it/s]
# Generating problems for 350: 100%|██████████| 10/10 [00:00<00:00, 2137.44it/s]
# Generating problems for 351: 100%|██████████| 10/10 [00:00<00:00, 2140.72it/s]
# Generating problems for 352: 100%|██████████| 10/10 [00:00<00:00, 2536.93it/s]
# Generating problems for 353: 100%|██████████| 10/10 [00:00<00:00, 2158.90it/s]
# Generating problems for 354: 100%|██████████| 10/10 [00:00<00:00, 1496.52it/s]
# Generating problems for 355: 100%|██████████| 10/10 [00:00<00:00, 2068.91it/s]
# Generating problems for 356: 100%|██████████| 10/10 [00:00<00:00, 2304.56it/s]
# Generating problems for 357: 100%|██████████| 8/8 [00:00<00:00, 2368.33it/s]
# Generating problems for 358: 100%|██████████| 8/8 [00:00<00:00, 2151.34it/s]
# Generating problems for 359: 100%|██████████| 8/8 [00:00<00:00, 2221.71it/s]
# Generating problems for 360: 100%|██████████| 8/8 [00:00<00:00, 2631.93it/s]
# Generating problems for 361: 100%|██████████| 8/8 [00:00<00:00, 2008.29it/s]
# Generating problems for 362: 100%|██████████| 8/8 [00:00<00:00, 2352.22it/s]
# Generating problems for 363: 100%|██████████| 10/10 [00:00<00:00, 2046.70it/s]
# Generating problems for 364: 100%|██████████| 10/10 [00:00<00:00, 2493.94it/s]
# Generating problems for 365: 100%|██████████| 10/10 [00:00<00:00, 2786.17it/s]
# Generating problems for 366: 100%|██████████| 10/10 [00:00<00:00, 1967.49it/s]
# Generating problems for 367: 100%|██████████| 10/10 [00:00<00:00, 1092.84it/s]
# Generating problems for 368: 100%|██████████| 10/10 [00:00<00:00, 2446.66it/s]
# Generating problems for 369: 100%|██████████| 10/10 [00:00<00:00, 2509.31it/s]
# Generating problems for 370: 100%|██████████| 10/10 [00:00<00:00, 1821.16it/s]
# Generating problems for 371: 100%|██████████| 10/10 [00:00<00:00, 2044.71it/s]
# Generating problems for 372: 100%|██████████| 9/9 [00:00<00:00, 1949.03it/s]
# Generating problems for 373: 100%|██████████| 9/9 [00:00<00:00, 1960.26it/s]
# Generating problems for 374: 100%|██████████| 9/9 [00:00<00:00, 2363.43it/s]
# Generating problems for 375: 100%|██████████| 9/9 [00:00<00:00, 2199.94it/s]
# Generating problems for 376: 100%|██████████| 9/9 [00:00<00:00, 2132.82it/s]
# Generating problems for 377: 100%|██████████| 9/9 [00:00<00:00, 2585.18it/s]
# Generating problems for 378: 100%|██████████| 10/10 [00:00<00:00, 1845.11it/s]
# Generating problems for 379: 100%|██████████| 10/10 [00:00<00:00, 2101.88it/s]
# Generating problems for 380: 100%|██████████| 10/10 [00:00<00:00, 2324.74it/s]
# Generating problems for 381: 100%|██████████| 10/10 [00:00<00:00, 1825.20it/s]
# Generating problems for 382: 100%|██████████| 10/10 [00:00<00:00, 1596.67it/s]
# Generating problems for 383: 100%|██████████| 10/10 [00:00<00:00, 1715.67it/s]
# Generating problems for 384: 100%|██████████| 10/10 [00:00<00:00, 2015.81it/s]
# Generating problems for 385: 100%|██████████| 10/10 [00:00<00:00, 1855.89it/s]
# Generating problems for 386: 100%|██████████| 9/9 [00:00<00:00, 1648.13it/s]
# Generating problems for 387: 100%|██████████| 9/9 [00:00<00:00, 1865.79it/s]
# Generating problems for 388: 100%|██████████| 9/9 [00:00<00:00, 2258.65it/s]
# Generating problems for 389: 100%|██████████| 9/9 [00:00<00:00, 1981.35it/s]
# Generating problems for 390: 100%|██████████| 9/9 [00:00<00:00, 1580.50it/s]
# Generating problems for 391: 100%|██████████| 3/3 [00:00<00:00, 1432.97it/s]
# Generating problems for 392: 100%|██████████| 3/3 [00:00<00:00, 1609.27it/s]
# Generating problems for 393: 100%|██████████| 3/3 [00:00<00:00, 1721.56it/s]
# Generating problems for 394: 100%|██████████| 10/10 [00:00<00:00, 1522.32it/s]
# Generating problems for 395: 100%|██████████| 10/10 [00:00<00:00, 1905.20it/s]
# Generating problems for 396: 100%|██████████| 8/8 [00:00<00:00, 1939.67it/s]
# Generating problems for 397: 100%|██████████| 8/8 [00:00<00:00, 1678.48it/s]
# Generating problems for 398: 100%|██████████| 8/8 [00:00<00:00, 2048.75it/s]
# Generating problems for 399: 100%|██████████| 8/8 [00:00<00:00, 1880.54it/s]
# Generating problems for 400: 100%|██████████| 9/9 [00:00<00:00, 2333.34it/s]
# Generating problems for 401: 100%|██████████| 9/9 [00:00<00:00, 2298.67it/s]
# Generating problems for 402: 100%|██████████| 10/10 [00:00<00:00, 2289.84it/s]
# Generating problems for 403: 100%|██████████| 10/10 [00:00<00:00, 2028.29it/s]
# Generating problems for 404: 100%|██████████| 10/10 [00:00<00:00, 2460.29it/s]
# Generating problems for 405: 100%|██████████| 10/10 [00:00<00:00, 2557.03it/s]
# Generating problems for 406: 100%|██████████| 10/10 [00:00<00:00, 1947.76it/s]
# Generating problems for 407: 100%|██████████| 10/10 [00:00<00:00, 1940.91it/s]
# Generating problems for 408: 100%|██████████| 10/10 [00:00<00:00, 1283.64it/s]
# Generating problems for 409: 100%|██████████| 10/10 [00:00<00:00, 1266.43it/s]
# Generating problems for 410: 100%|██████████| 10/10 [00:00<00:00, 1835.50it/s]
# Generating problems for 411: 100%|██████████| 10/10 [00:00<00:00, 1618.92it/s]
# Generating problems for 412: 100%|██████████| 10/10 [00:00<00:00, 1833.17it/s]
# Generating problems for 413: 100%|██████████| 10/10 [00:00<00:00, 1873.04it/s]
# Generating problems for 414: 100%|██████████| 10/10 [00:00<00:00, 2059.36it/s]
# Generating problems for 415: 100%|██████████| 10/10 [00:00<00:00, 706.39it/s]
# Generating problems for 416: 100%|██████████| 10/10 [00:00<00:00, 906.01it/s]
# Generating problems for 417: 100%|██████████| 10/10 [00:00<00:00, 693.02it/s]
# Generating problems for 418: 100%|██████████| 10/10 [00:00<00:00, 697.34it/s]
# Generating problems for 419: 100%|██████████| 10/10 [00:00<00:00, 733.78it/s]
# Generating problems for 420: 100%|██████████| 10/10 [00:00<00:00, 1869.95it/s]
# Generating problems for 421: 100%|██████████| 10/10 [00:00<00:00, 1758.62it/s]
# Generating problems for 422: 100%|██████████| 10/10 [00:00<00:00, 2903.44it/s]
# Generating problems for 423: 100%|██████████| 10/10 [00:00<00:00, 2177.39it/s]
# Generating problems for 424: 100%|██████████| 10/10 [00:00<00:00, 459.83it/s]
# Generating problems for 425: 100%|██████████| 9/9 [00:00<00:00, 1500.71it/s]
# Generating problems for 426: 100%|██████████| 9/9 [00:00<00:00, 2139.59it/s]
# Generating problems for 427: 100%|██████████| 9/9 [00:00<00:00, 2151.66it/s]
# Generating problems for 428: 100%|██████████| 9/9 [00:00<00:00, 1645.83it/s]
# Generating problems for 429: 100%|██████████| 9/9 [00:00<00:00, 2378.02it/s]
# Generating problems for 430: 100%|██████████| 10/10 [00:00<00:00, 858.91it/s]
# Generating problems for 431: 100%|██████████| 10/10 [00:00<00:00, 2040.73it/s]
# Generating problems for 432: 100%|██████████| 10/10 [00:00<00:00, 2550.81it/s]
# Generating problems for 433: 100%|██████████| 10/10 [00:00<00:00, 2047.00it/s]
# Generating problems for 434: 100%|██████████| 10/10 [00:00<00:00, 1636.87it/s]
# Generating problems for 435: 100%|██████████| 10/10 [00:00<00:00, 1828.22it/s]
# Generating problems for 436: 100%|██████████| 10/10 [00:00<00:00, 2116.95it/s]
# Generating problems for 437: 100%|██████████| 10/10 [00:00<00:00, 2081.23it/s]
# Generating problems for 438: 100%|██████████| 10/10 [00:00<00:00, 2057.54it/s]
# Generating problems for 439: 100%|██████████| 10/10 [00:00<00:00, 2188.75it/s]
# Generating problems for 440: 100%|██████████| 7/7 [00:00<00:00, 2446.07it/s]
# Generating problems for 441: 100%|██████████| 7/7 [00:00<00:00, 1885.44it/s]
# Generating problems for 442: 100%|██████████| 7/7 [00:00<00:00, 1402.17it/s]
# Generating problems for 443: 100%|██████████| 8/8 [00:00<00:00, 2412.43it/s]
# Generating problems for 444: 100%|██████████| 8/8 [00:00<00:00, 1370.02it/s]
# Generating problems for 445: 100%|██████████| 8/8 [00:00<00:00, 1282.51it/s]
# Generating problems for 446: 100%|██████████| 8/8 [00:00<00:00, 1283.59it/s]
# Generating problems for 447: 100%|██████████| 9/9 [00:00<00:00, 1827.67it/s]
# Generating problems for 448: 100%|██████████| 7/7 [00:00<00:00, 1894.81it/s]
# Generating problems for 449: 100%|██████████| 7/7 [00:00<00:00, 1173.19it/s]
# Generating problems for 450: 100%|██████████| 7/7 [00:00<00:00, 1258.58it/s]
# Generating problems for 451: 100%|██████████| 8/8 [00:00<00:00, 1345.57it/s]
# Generating problems for 452: 100%|██████████| 8/8 [00:00<00:00, 1255.87it/s]
# Generating problems for 453: 100%|██████████| 7/7 [00:00<00:00, 2584.29it/s]
# Generating problems for 454: 100%|██████████| 7/7 [00:00<00:00, 2159.15it/s]
# Generating problems for 455: 100%|██████████| 7/7 [00:00<00:00, 2128.32it/s]
# Generating problems for 456: 100%|██████████| 10/10 [00:00<00:00, 1689.48it/s]
# Generating problems for 457: 100%|██████████| 10/10 [00:00<00:00, 1980.03it/s]
# Generating problems for 458: 100%|██████████| 10/10 [00:00<00:00, 2172.65it/s]
# Generating problems for 459: 100%|██████████| 10/10 [00:00<00:00, 1249.57it/s]
# Generating problems for 460: 100%|██████████| 9/9 [00:00<00:00, 1356.31it/s]
# Generating problems for 461: 100%|██████████| 9/9 [00:00<00:00, 2177.98it/s]
# Generating problems for 462: 100%|██████████| 9/9 [00:00<00:00, 1853.79it/s]
# Generating problems for 463: 100%|██████████| 10/10 [00:00<00:00, 2231.13it/s]
# Generating problems for 464: 100%|██████████| 10/10 [00:00<00:00, 2162.68it/s]
# Generating problems for 465: 100%|██████████| 10/10 [00:00<00:00, 2104.31it/s]
# Generating problems for 466: 100%|██████████| 10/10 [00:00<00:00, 2091.82it/s]
# Generating problems for 467: 100%|██████████| 9/9 [00:00<00:00, 1908.43it/s]
# Generating problems for 468: 100%|██████████| 9/9 [00:00<00:00, 1550.32it/s]
# Generating problems for 469: 100%|██████████| 4/4 [00:00<00:00, 2330.82it/s]
# Generating problems for 470: 100%|██████████| 4/4 [00:00<00:00, 1961.10it/s]
# Generating problems for 471: 100%|██████████| 4/4 [00:00<00:00, 2122.35it/s]
# Generating problems for 472: 100%|██████████| 10/10 [00:00<00:00, 1827.34it/s]
# Generating problems for 473: 100%|██████████| 10/10 [00:00<00:00, 2181.47it/s]
# Generating problems for 474: 100%|██████████| 10/10 [00:00<00:00, 1334.24it/s]
# Generating problems for 475: 100%|██████████| 10/10 [00:00<00:00, 1859.92it/s]
# Generating problems for 476: 100%|██████████| 7/7 [00:00<00:00, 2501.29it/s]
# Generating problems for 477: 100%|██████████| 7/7 [00:00<00:00, 2624.72it/s]
# Generating problems for 478: 100%|██████████| 7/7 [00:00<00:00, 1129.02it/s]
# Generating problems for 479: 100%|██████████| 7/7 [00:00<00:00, 1424.21it/s]
# Generating problems for 480: 100%|██████████| 6/6 [00:00<00:00, 2072.11it/s]
# Generating problems for 481: 100%|██████████| 6/6 [00:00<00:00, 1679.63it/s]
# Generating problems for 482: 100%|██████████| 6/6 [00:00<00:00, 2244.34it/s]
# Generating problems for 483: 100%|██████████| 9/9 [00:00<00:00, 1822.29it/s]
# Generating problems for 484: 100%|██████████| 9/9 [00:00<00:00, 1692.77it/s]
# Generating problems for 485: 100%|██████████| 8/8 [00:00<00:00, 1313.95it/s]
# Generating problems for 486: 100%|██████████| 8/8 [00:00<00:00, 1420.23it/s]
# Generating problems for 487: 100%|██████████| 8/8 [00:00<00:00, 1103.07it/s]
# Generating problems for 488: 100%|██████████| 8/8 [00:00<00:00, 1151.93it/s]
# Generating problems for 489: 100%|██████████| 8/8 [00:00<00:00, 2284.32it/s]
# Generating problems for 490: 100%|██████████| 8/8 [00:00<00:00, 1031.08it/s]
# Generating problems for 491: 100%|██████████| 8/8 [00:00<00:00, 2028.93it/s]
# Generating problems for 492: 100%|██████████| 9/9 [00:00<00:00, 2319.72it/s]
# Generating problems for 493: 100%|██████████| 9/9 [00:00<00:00, 1369.30it/s]
# Generating problems for 494: 100%|██████████| 9/9 [00:00<00:00, 2415.46it/s]
# Generating problems for 495: 100%|██████████| 10/10 [00:00<00:00, 1660.58it/s]
# Generating problems for 496: 100%|██████████| 10/10 [00:00<00:00, 2100.41it/s]
# Generating problems for 497: 100%|██████████| 8/8 [00:00<00:00, 1843.95it/s]
# Generating problems for 498: 100%|██████████| 8/8 [00:00<00:00, 1838.10it/s]
# Generating problems for 499: 100%|██████████| 8/8 [00:00<00:00, 1426.94it/s]
# Generating problems for 500: 100%|██████████| 8/8 [00:00<00:00, 957.82it/s]
# Generating problems for 501: 100%|██████████| 9/9 [00:00<00:00, 1522.13it/s]
# Generating problems for 502: 100%|██████████| 9/9 [00:00<00:00, 1134.48it/s]
# Generating problems for 503: 100%|██████████| 9/9 [00:00<00:00, 1725.26it/s]
# Generating problems for 504: 100%|██████████| 9/9 [00:00<00:00, 2338.11it/s]
# Generating problems for 505: 100%|██████████| 10/10 [00:00<00:00, 1692.07it/s]
# Generating problems for 506: 100%|██████████| 10/10 [00:00<00:00, 2089.63it/s]
# Generating problems for 507: 100%|██████████| 10/10 [00:00<00:00, 2525.17it/s]
# Generating problems for 508: 100%|██████████| 10/10 [00:00<00:00, 1587.91it/s]
# Generating problems for 509: 100%|██████████| 10/10 [00:00<00:00, 2265.60it/s]
# Generating problems for 510: 100%|██████████| 10/10 [00:00<00:00, 1827.19it/s]
# Generating problems for 511: 100%|██████████| 9/9 [00:00<00:00, 1744.15it/s]
# Generating problems for 512: 100%|██████████| 9/9 [00:00<00:00, 2461.61it/s]
# Generating problems for 513: 100%|██████████| 9/9 [00:00<00:00, 2142.02it/s]
# Generating problems for 514: 100%|██████████| 8/8 [00:00<00:00, 2258.34it/s]
# Generating problems for 515: 100%|██████████| 8/8 [00:00<00:00, 1658.24it/s]
# Generating problems for 516: 100%|██████████| 8/8 [00:00<00:00, 849.85it/s]
# Generating problems for 517: 100%|██████████| 8/8 [00:00<00:00, 2667.50it/s]
# Generating problems for 518: 100%|██████████| 8/8 [00:00<00:00, 2360.49it/s]
# Generating problems for 519: 100%|██████████| 8/8 [00:00<00:00, 1400.73it/s]
# Generating problems for 520: 100%|██████████| 8/8 [00:00<00:00, 1312.62it/s]
# Generating problems for 521: 100%|██████████| 10/10 [00:00<00:00, 1720.03it/s]
# Generating problems for 522: 100%|██████████| 10/10 [00:00<00:00, 1194.58it/s]
# Generating problems for 523: 100%|██████████| 10/10 [00:00<00:00, 1581.92it/s]
# Generating problems for 524: 100%|██████████| 9/9 [00:00<00:00, 1995.07it/s]
# Generating problems for 525: 100%|██████████| 9/9 [00:00<00:00, 2893.07it/s]
# Generating problems for 526: 100%|██████████| 9/9 [00:00<00:00, 1792.27it/s]
# Generating problems for 527: 100%|██████████| 9/9 [00:00<00:00, 1334.49it/s]
# Generating problems for 528: 100%|██████████| 6/6 [00:00<00:00, 1584.25it/s]
# Generating problems for 529: 100%|██████████| 6/6 [00:00<00:00, 1536.94it/s]
# Generating problems for 530: 100%|██████████| 6/6 [00:00<00:00, 1839.07it/s]
# Generating problems for 531: 100%|██████████| 8/8 [00:00<00:00, 1103.36it/s]
# Generating problems for 532: 100%|██████████| 8/8 [00:00<00:00, 1175.29it/s]
# Generating problems for 533: 100%|██████████| 8/8 [00:00<00:00, 1595.10it/s]
# Generating problems for 534: 100%|██████████| 8/8 [00:00<00:00, 816.89it/s]
# Generating problems for 535: 100%|██████████| 9/9 [00:00<00:00, 1713.90it/s]
# Generating problems for 536: 100%|██████████| 9/9 [00:00<00:00, 2202.12it/s]
# Generating problems for 537: 100%|██████████| 9/9 [00:00<00:00, 1743.27it/s]
# Generating problems for 538: 100%|██████████| 8/8 [00:00<00:00, 1598.90it/s]
# Generating problems for 539: 100%|██████████| 8/8 [00:00<00:00, 2284.63it/s]
# Generating problems for 540: 100%|██████████| 8/8 [00:00<00:00, 1253.81it/s]
# Generating problems for 541: 100%|██████████| 9/9 [00:00<00:00, 2392.19it/s]
# Generating problems for 542: 100%|██████████| 9/9 [00:00<00:00, 3076.76it/s]
# Generating problems for 543: 100%|██████████| 9/9 [00:00<00:00, 3027.65it/s]
# Generating problems for 544: 100%|██████████| 9/9 [00:00<00:00, 2346.68it/s]
# Generating problems for 545: 100%|██████████| 10/10 [00:00<00:00, 978.81it/s]
# Generating problems for 546: 100%|██████████| 10/10 [00:00<00:00, 1701.27it/s]
# Generating problems for 547: 100%|██████████| 10/10 [00:00<00:00, 1020.24it/s]
# Generating problems for 548: 100%|██████████| 10/10 [00:00<00:00, 1521.38it/s]
# Generating problems for 549: 100%|██████████| 9/9 [00:00<00:00, 1256.36it/s]
# Generating problems for 550: 100%|██████████| 9/9 [00:00<00:00, 1377.89it/s]
# Generating problems for 551: 100%|██████████| 9/9 [00:00<00:00, 2668.13it/s]
# Generating problems for 552: 100%|██████████| 8/8 [00:00<00:00, 1998.12it/s]
# Generating problems for 553: 100%|██████████| 8/8 [00:00<00:00, 2334.71it/s]
# Generating problems for 554: 100%|██████████| 10/10 [00:00<00:00, 1541.74it/s]
# Generating problems for 555: 100%|██████████| 10/10 [00:00<00:00, 1446.01it/s]
# Generating problems for 556: 100%|██████████| 10/10 [00:00<00:00, 1120.84it/s]
# Generating problems for 557: 100%|██████████| 10/10 [00:00<00:00, 1832.85it/s]
# Generating problems for 558: 100%|██████████| 10/10 [00:00<00:00, 2260.11it/s]
# Generating problems for 559: 100%|██████████| 10/10 [00:00<00:00, 2307.61it/s]
# Generating problems for 560: 100%|██████████| 10/10 [00:00<00:00, 2272.23it/s]
# Generating problems for 561: 100%|██████████| 10/10 [00:00<00:00, 1878.75it/s]
# Generating problems for 562: 100%|██████████| 10/10 [00:00<00:00, 2031.93it/s]
# Generating problems for 563: 100%|██████████| 10/10 [00:00<00:00, 1113.82it/s]
# Generating problems for 564: 100%|██████████| 10/10 [00:00<00:00, 1755.97it/s]
# Generating problems for 565: 100%|██████████| 10/10 [00:00<00:00, 1900.97it/s]
# Generating problems for 566: 100%|██████████| 10/10 [00:00<00:00, 2029.27it/s]
# Generating problems for 567: 100%|██████████| 10/10 [00:00<00:00, 2598.22it/s]
# Generating problems for 568: 100%|██████████| 10/10 [00:00<00:00, 2367.12it/s]
# Generating problems for 569: 100%|██████████| 10/10 [00:00<00:00, 2393.46it/s]
# Generating problems for 570: 100%|██████████| 10/10 [00:00<00:00, 1967.49it/s]
# Generating problems for 571: 100%|██████████| 10/10 [00:00<00:00, 1931.61it/s]
# Generating problems for 572: 100%|██████████| 10/10 [00:00<00:00, 1887.03it/s]
# Generating problems for 573: 100%|██████████| 10/10 [00:00<00:00, 1421.46it/s]
# Generating problems for 574: 100%|██████████| 10/10 [00:00<00:00, 2044.71it/s]
# Generating problems for 575: 100%|██████████| 10/10 [00:00<00:00, 1655.93it/s]
# Generating problems for 576: 100%|██████████| 8/8 [00:00<00:00, 1798.97it/s]
# Generating problems for 577: 100%|██████████| 8/8 [00:00<00:00, 2130.71it/s]
# Generating problems for 578: 100%|██████████| 8/8 [00:00<00:00, 2090.88it/s]
# Generating problems for 579: 100%|██████████| 8/8 [00:00<00:00, 2054.14it/s]
# Generating problems for 580: 100%|██████████| 7/7 [00:00<00:00, 2435.72it/s]
# Generating problems for 581: 100%|██████████| 7/7 [00:00<00:00, 2047.00it/s]
# Generating problems for 582: 100%|██████████| 10/10 [00:00<00:00, 1839.12it/s]
# Generating problems for 583: 100%|██████████| 10/10 [00:00<00:00, 2300.52it/s]
# Generating problems for 584: 100%|██████████| 10/10 [00:00<00:00, 2251.73it/s]
# Generating problems for 585: 100%|██████████| 10/10 [00:00<00:00, 1385.36it/s]
# Generating problems for 586: 100%|██████████| 10/10 [00:00<00:00, 2415.24it/s]
# Generating problems for 587: 100%|██████████| 10/10 [00:00<00:00, 2306.59it/s]
# Generating problems for 588: 100%|██████████| 5/5 [00:00<00:00, 1840.25it/s]
# Generating problems for 589: 100%|██████████| 5/5 [00:00<00:00, 2395.92it/s]
# Generating problems for 590: 100%|██████████| 5/5 [00:00<00:00, 2004.93it/s]
# Generating problems for 591: 100%|██████████| 5/5 [00:00<00:00, 2834.76it/s]
# Generating problems for 592: 100%|██████████| 5/5 [00:00<00:00, 1006.26it/s]
# Generating problems for 593: 100%|██████████| 7/7 [00:00<00:00, 1170.38it/s]
# Generating problems for 594: 100%|██████████| 7/7 [00:00<00:00, 1362.99it/s]
# Generating problems for 595: 100%|██████████| 7/7 [00:00<00:00, 2302.57it/s]
# Generating problems for 596: 100%|██████████| 10/10 [00:00<00:00, 1946.67it/s]
# Generating problems for 597: 100%|██████████| 10/10 [00:00<00:00, 2139.51it/s]
# Generating problems for 598: 100%|██████████| 10/10 [00:00<00:00, 1235.54it/s]
# Generating problems for 599: 100%|██████████| 10/10 [00:00<00:00, 1540.44it/s]
# Generating problems for 600: 100%|██████████| 10/10 [00:00<00:00, 2229.47it/s]
# Generating problems for 601: 100%|██████████| 10/10 [00:00<00:00, 1791.60it/s]
# Generating problems for 602: 100%|██████████| 8/8 [00:00<00:00, 2403.27it/s]
# Generating problems for 603: 100%|██████████| 8/8 [00:00<00:00, 1971.35it/s]
# Generating problems for 604: 100%|██████████| 8/8 [00:00<00:00, 3060.98it/s]
# Generating problems for 605: 100%|██████████| 10/10 [00:00<00:00, 2350.01it/s]
# Generating problems for 606: 100%|██████████| 10/10 [00:00<00:00, 2269.03it/s]
# Generating problems for 607: 100%|██████████| 10/10 [00:00<00:00, 2025.94it/s]
# Generating problems for 608: 100%|██████████| 8/8 [00:00<00:00, 2736.46it/s]
# Generating problems for 609: 100%|██████████| 8/8 [00:00<00:00, 1887.31it/s]
# Generating problems for 610: 100%|██████████| 6/6 [00:00<00:00, 2029.01it/s]
# Generating problems for 611: 100%|██████████| 6/6 [00:00<00:00, 1937.32it/s]
# Generating problems for 612: 100%|██████████| 6/6 [00:00<00:00, 2576.62it/s]
# Generating problems for 613: 100%|██████████| 8/8 [00:00<00:00, 2475.98it/s]
# Generating problems for 614: 100%|██████████| 8/8 [00:00<00:00, 1959.04it/s]
# Generating problems for 615: 100%|██████████| 8/8 [00:00<00:00, 2078.83it/s]
# Generating problems for 616: 100%|██████████| 10/10 [00:00<00:00, 1980.22it/s]
# ...
# Generating problems for 1648: 100%|██████████| 8/8 [00:00<00:00, 873.95it/s]
# Generating problems for 1649: 100%|██████████| 8/8 [00:00<00:00, 1269.22it/s]
# Generating problems for 1650: 100%|██████████| 8/8 [00:00<00:00, 816.69it/s]
# Generating problems for 1651: 100%|██████████| 7/7 [00:00<00:00, 794.29it/s]
# Generating problems for 1652: 100%|██████████| 7/7 [00:00<00:00, 2462.48it/s]
# Generating problems for 1653: 100%|██████████| 7/7 [00:00<00:00, 1978.31it/s]
# Generating problems for 1654: 100%|██████████| 7/7 [00:00<00:00, 1911.22it/s]
# Generating problems for 1655: 100%|██████████| 7/7 [00:00<00:00, 3225.32it/s]
# Generating problems for 1656: 100%|██████████| 7/7 [00:00<00:00, 1894.57it/s]
# Generating problems for 1657: 100%|██████████| 7/7 [00:00<00:00, 1838.46it/s]
# Generating problems for 1658: 100%|██████████| 10/10 [00:00<00:00, 1308.80it/s]
# Generating problems for 1659: 100%|██████████| 10/10 [00:00<00:00, 2081.44it/s]
# Generating problems for 1660: 100%|██████████| 10/10 [00:00<00:00, 2534.78it/s]
# Generating problems for 1661: 100%|██████████| 10/10 [00:00<00:00, 2002.34it/s]
# Generating problems for 1662: 100%|██████████| 10/10 [00:00<00:00, 2028.19it/s]
# Generating problems for 1663: 100%|██████████| 10/10 [00:00<00:00, 1674.77it/s]
# Generating problems for 1664: 100%|██████████| 10/10 [00:00<00:00, 1627.97it/s]
# Generating problems for 1665: 100%|██████████| 10/10 [00:00<00:00, 2388.96it/s]
# Generating problems for 1666: 100%|██████████| 10/10 [00:00<00:00, 2370.47it/s]
# Generating problems for 1667: 100%|██████████| 10/10 [00:00<00:00, 1340.46it/s]
# Generating problems for 1668: 100%|██████████| 10/10 [00:00<00:00, 1235.29it/s]
# Generating problems for 1669: 100%|██████████| 10/10 [00:00<00:00, 1310.06it/s]
# Generating problems for 1670: 100%|██████████| 10/10 [00:00<00:00, 1312.69it/s]
# Generating problems for 1671: 100%|██████████| 10/10 [00:00<00:00, 1413.79it/s]
# Generating problems for 1672: 100%|██████████| 10/10 [00:00<00:00, 1839.77it/s]
# Generating problems for 1673: 100%|██████████| 9/9 [00:00<00:00, 1926.05it/s]
# Generating problems for 1674: 100%|██████████| 9/9 [00:00<00:00, 1545.56it/s]
# Generating problems for 1675: 100%|██████████| 9/9 [00:00<00:00, 1890.94it/s]
# Generating problems for 1676: 100%|██████████| 10/10 [00:00<00:00, 2191.27it/s]
# Generating problems for 1677: 100%|██████████| 10/10 [00:00<00:00, 1154.53it/s]
# Generating problems for 1678: 100%|██████████| 10/10 [00:00<00:00, 1458.23it/s]
# Generating problems for 1679: 100%|██████████| 9/9 [00:00<00:00, 1753.80it/s]
# Generating problems for 1680: 100%|██████████| 9/9 [00:00<00:00, 1872.46it/s]
# Generating problems for 1681: 100%|██████████| 9/9 [00:00<00:00, 1835.85it/s]
# Generating problems for 1682: 100%|██████████| 9/9 [00:00<00:00, 1672.22it/s]
# Generating problems for 1683: 100%|██████████| 7/7 [00:00<00:00, 1995.93it/s]
# Generating problems for 1684: 100%|██████████| 7/7 [00:00<00:00, 1678.30it/s]
# Generating problems for 1685: 100%|██████████| 7/7 [00:00<00:00, 1579.78it/s]
# Generating problems for 1686: 100%|██████████| 7/7 [00:00<00:00, 1650.65it/s]
# Generating problems for 1687: 100%|██████████| 7/7 [00:00<00:00, 1727.98it/s]
# Generating problems for 1688: 100%|██████████| 8/8 [00:00<00:00, 2157.01it/s]
# Generating problems for 1689: 100%|██████████| 8/8 [00:00<00:00, 1179.21it/s]
# Generating problems for 1690: 100%|██████████| 8/8 [00:00<00:00, 1856.09it/s]
# Generating problems for 1691: 100%|██████████| 10/10 [00:00<00:00, 2346.20it/s]
# Generating problems for 1692: 100%|██████████| 10/10 [00:00<00:00, 2699.56it/s]
# Generating problems for 1693: 100%|██████████| 10/10 [00:00<00:00, 2013.97it/s]
# Generating problems for 1694: 100%|██████████| 7/7 [00:00<00:00, 1338.02it/s]
# Generating problems for 1695: 100%|██████████| 7/7 [00:00<00:00, 1257.45it/s]
# Generating problems for 1696: 100%|██████████| 7/7 [00:00<00:00, 735.42it/s]
# Generating problems for 1697: 100%|██████████| 7/7 [00:00<00:00, 1470.21it/s]
# Generating problems for 1698: 100%|██████████| 10/10 [00:00<00:00, 1842.11it/s]
# Generating problems for 1699: 100%|██████████| 10/10 [00:00<00:00, 1835.10it/s]
# Generating problems for 1700: 100%|██████████| 10/10 [00:00<00:00, 1307.53it/s]
# Generating problems for 1701: 100%|██████████| 10/10 [00:00<00:00, 1432.77it/s]
# Generating problems for 1702: 100%|██████████| 10/10 [00:00<00:00, 1771.47it/s]
# Generating problems for 1703: 100%|██████████| 10/10 [00:00<00:00, 1903.30it/s]
# Generating problems for 1704: 100%|██████████| 10/10 [00:00<00:00, 1336.53it/s]
# Generating problems for 1705: 100%|██████████| 10/10 [00:00<00:00, 2524.71it/s]
# Generating problems for 1706: 100%|██████████| 8/8 [00:00<00:00, 1036.69it/s]
# Generating problems for 1707: 100%|██████████| 8/8 [00:00<00:00, 1015.66it/s]
# Generating problems for 1708: 100%|██████████| 8/8 [00:00<00:00, 1330.42it/s]
# Generating problems for 1709: 100%|██████████| 8/8 [00:00<00:00, 1238.67it/s]
# Generating problems for 1710: 100%|██████████| 8/8 [00:00<00:00, 2042.51it/s]
# Generating problems for 1711: 100%|██████████| 8/8 [00:00<00:00, 2418.34it/s]
# Generating problems for 1712: 100%|██████████| 8/8 [00:00<00:00, 1571.49it/s]
# Generating problems for 1713: 100%|██████████| 10/10 [00:00<00:00, 1904.86it/s]
# Generating problems for 1714: 100%|██████████| 10/10 [00:00<00:00, 1887.46it/s]
# Generating problems for 1715: 100%|██████████| 10/10 [00:00<00:00, 1514.57it/s]
# Generating problems for 1716: 100%|██████████| 10/10 [00:00<00:00, 1159.70it/s]
# Generating problems for 1717: 100%|██████████| 10/10 [00:00<00:00, 1379.12it/s]
# Generating problems for 1718: 100%|██████████| 10/10 [00:00<00:00, 1140.25it/s]
# Generating problems for 1719: 100%|██████████| 10/10 [00:00<00:00, 1419.92it/s]
# Generating problems for 1720: 100%|██████████| 8/8 [00:00<00:00, 1472.14it/s]
# Generating problems for 1721: 100%|██████████| 8/8 [00:00<00:00, 1246.82it/s]
# Generating problems for 1722: 100%|██████████| 8/8 [00:00<00:00, 933.86it/s]
# Generating problems for 1723: 100%|██████████| 8/8 [00:00<00:00, 1591.31it/s]
# Generating problems for 1724: 100%|██████████| 8/8 [00:00<00:00, 1631.31it/s]
# Generating problems for 1725: 100%|██████████| 8/8 [00:00<00:00, 1581.26it/s]
# Generating problems for 1726: 100%|██████████| 8/8 [00:00<00:00, 1152.60it/s]
# Generating problems for 1727: 100%|██████████| 6/6 [00:00<00:00, 1753.23it/s]
# Generating problems for 1728: 100%|██████████| 6/6 [00:00<00:00, 1661.66it/s]
# Generating problems for 1729: 100%|██████████| 6/6 [00:00<00:00, 1563.58it/s]
# Generating problems for 1730: 100%|██████████| 6/6 [00:00<00:00, 1704.89it/s]
# Generating problems for 1731: 100%|██████████| 10/10 [00:00<00:00, 1297.30it/s]
# Generating problems for 1732: 100%|██████████| 10/10 [00:00<00:00, 1113.58it/s]
# Generating problems for 1733: 100%|██████████| 10/10 [00:00<00:00, 1037.68it/s]
# Generating problems for 1734: 100%|██████████| 4/4 [00:00<00:00, 1421.92it/s]
# Generating problems for 1735: 100%|██████████| 4/4 [00:00<00:00, 2070.24it/s]
# Generating problems for 1736: 100%|██████████| 4/4 [00:00<00:00, 1280.61it/s]
# Generating problems for 1737: 100%|██████████| 9/9 [00:00<00:00, 1738.93it/s]
# Generating problems for 1738: 100%|██████████| 9/9 [00:00<00:00, 2256.35it/s]
# Generating problems for 1739: 100%|██████████| 10/10 [00:00<00:00, 2424.59it/s]
# Generating problems for 1740: 100%|██████████| 10/10 [00:00<00:00, 1538.23it/s]
# Generating problems for 1741: 100%|██████████| 10/10 [00:00<00:00, 1627.34it/s]
# Generating problems for 1742: 100%|██████████| 10/10 [00:00<00:00, 1383.39it/s]
# Generating problems for 1743: 100%|██████████| 10/10 [00:00<00:00, 1960.50it/s]
# Generating problems for 1744: 100%|██████████| 10/10 [00:00<00:00, 1638.59it/s]
# Generating problems for 1745: 100%|██████████| 8/8 [00:00<00:00, 2400.00it/s]
# Generating problems for 1746: 100%|██████████| 8/8 [00:00<00:00, 2089.71it/s]
# Generating problems for 1747: 100%|██████████| 8/8 [00:00<00:00, 2165.22it/s]
# Generating problems for 1748: 100%|██████████| 8/8 [00:00<00:00, 2053.26it/s]
# Generating problems for 1749: 100%|██████████| 8/8 [00:00<00:00, 1905.20it/s]
# Generating problems for 1750: 100%|██████████| 9/9 [00:00<00:00, 1481.74it/s]
# Generating problems for 1751: 100%|██████████| 9/9 [00:00<00:00, 1382.54it/s]
# Generating problems for 1752: 100%|██████████| 9/9 [00:00<00:00, 2015.74it/s]
# Generating problems for 1753: 100%|██████████| 9/9 [00:00<00:00, 1415.35it/s]
# Generating problems for 1754: 100%|██████████| 9/9 [00:00<00:00, 2594.77it/s]
# Generating problems for 1755: 100%|██████████| 10/10 [00:00<00:00, 1990.75it/s]
# Generating problems for 1756: 100%|██████████| 10/10 [00:00<00:00, 2012.04it/s]
# Generating problems for 1757: 100%|██████████| 10/10 [00:00<00:00, 1974.81it/s]
# Generating problems for 1758: 100%|██████████| 10/10 [00:00<00:00, 2501.67it/s]
# Generating problems for 1759: 100%|██████████| 10/10 [00:00<00:00, 1505.22it/s]
# Generating problems for 1760: 100%|██████████| 10/10 [00:00<00:00, 2085.37it/s]
# Generating problems for 1761: 100%|██████████| 10/10 [00:00<00:00, 1568.02it/s]
# Generating problems for 1762: 100%|██████████| 10/10 [00:00<00:00, 1712.31it/s]
# Generating problems for 1763: 100%|██████████| 8/8 [00:00<00:00, 851.57it/s]
# Generating problems for 1764: 100%|██████████| 8/8 [00:00<00:00, 1205.52it/s]
# Generating problems for 1765: 100%|██████████| 8/8 [00:00<00:00, 759.77it/s]
# Generating problems for 1766: 100%|██████████| 8/8 [00:00<00:00, 535.18it/s]
# Generating problems for 1767: 100%|██████████| 10/10 [00:00<00:00, 750.48it/s]
# Generating problems for 1768: 100%|██████████| 10/10 [00:00<00:00, 934.27it/s]
# Generating problems for 1769: 100%|██████████| 10/10 [00:00<00:00, 810.43it/s]
# Generating problems for 1770: 100%|██████████| 10/10 [00:00<00:00, 1267.81it/s]
# Generating problems for 1771: 100%|██████████| 6/6 [00:00<00:00, 2399.95it/s]
# Generating problems for 1772: 100%|██████████| 6/6 [00:00<00:00, 2066.67it/s]
# Generating problems for 1773: 100%|██████████| 6/6 [00:00<00:00, 1723.33it/s]
# Generating problems for 1774: 100%|██████████| 6/6 [00:00<00:00, 2782.29it/s]
# Generating problems for 1775: 100%|██████████| 10/10 [00:00<00:00, 1353.39it/s]
# Generating problems for 1776: 100%|██████████| 10/10 [00:00<00:00, 1651.89it/s]
# Generating problems for 1777: 100%|██████████| 10/10 [00:00<00:00, 1555.23it/s]
# Generating problems for 1778: 100%|██████████| 5/5 [00:00<00:00, 2460.58it/s]
# Generating problems for 1779: 100%|██████████| 5/5 [00:00<00:00, 1854.57it/s]
# Generating problems for 1780: 100%|██████████| 5/5 [00:00<00:00, 1478.12it/s]
# Generating problems for 1781: 100%|██████████| 10/10 [00:00<00:00, 1864.30it/s]
# Generating problems for 1782: 100%|██████████| 10/10 [00:00<00:00, 2086.93it/s]
# Generating problems for 1783: 100%|██████████| 10/10 [00:00<00:00, 1290.20it/s]
# Generating problems for 1784: 100%|██████████| 8/8 [00:00<00:00, 1855.89it/s]
# Generating problems for 1785: 100%|██████████| 8/8 [00:00<00:00, 1845.37it/s]
# Generating problems for 1786: 100%|██████████| 8/8 [00:00<00:00, 1940.46it/s]
# Generating problems for 1787: 100%|██████████| 8/8 [00:00<00:00, 1674.46it/s]
# Generating problems for 1788: 100%|██████████| 8/8 [00:00<00:00, 1467.69it/s]
# Generating problems for 1789: 100%|██████████| 8/8 [00:00<00:00, 1863.62it/s]
# Generating problems for 1790: 100%|██████████| 9/9 [00:00<00:00, 1210.40it/s]
# Generating problems for 1791: 100%|██████████| 9/9 [00:00<00:00, 1052.64it/s]
# Generating problems for 1792: 100%|██████████| 10/10 [00:00<00:00, 1863.97it/s]
# Generating problems for 1793: 100%|██████████| 10/10 [00:00<00:00, 1675.31it/s]
# Generating problems for 1794: 100%|██████████| 10/10 [00:00<00:00, 1178.34it/s]
# Generating problems for 1795: 100%|██████████| 9/9 [00:00<00:00, 1746.25it/s]
# Generating problems for 1796: 100%|██████████| 9/9 [00:00<00:00, 1913.65it/s]
# Generating problems for 1797: 100%|██████████| 9/9 [00:00<00:00, 1539.19it/s]
# Generating problems for 1798: 100%|██████████| 9/9 [00:00<00:00, 1855.25it/s]
# Generating problems for 1799: 100%|██████████| 9/9 [00:00<00:00, 1324.98it/s]
# Generating problems for 1800: 100%|██████████| 10/10 [00:00<00:00, 1010.99it/s]
# Generating problems for 1801: 100%|██████████| 10/10 [00:00<00:00, 778.34it/s]
# Generating problems for 1802: 100%|██████████| 10/10 [00:00<00:00, 1155.20it/s]
# Generating problems for 1803: 100%|██████████| 9/9 [00:00<00:00, 2323.71it/s]
# Generating problems for 1804: 100%|██████████| 9/9 [00:00<00:00, 2048.67it/s]
# Generating problems for 1805: 100%|██████████| 9/9 [00:00<00:00, 1865.06it/s]
# Generating problems for 1806: 100%|██████████| 9/9 [00:00<00:00, 1811.88it/s]
# Generating problems for 1807: 100%|██████████| 9/9 [00:00<00:00, 2271.97it/s]
# Generating problems for 1808: 100%|██████████| 9/9 [00:00<00:00, 1094.04it/s]
# Generating problems for 1809: 100%|██████████| 9/9 [00:00<00:00, 1308.99it/s]
# Generating problems for 1810: 100%|██████████| 10/10 [00:00<00:00, 1847.71it/s]
# Generating problems for 1811: 100%|██████████| 10/10 [00:00<00:00, 889.38it/s]
# Generating problems for 1812: 100%|██████████| 10/10 [00:00<00:00, 1335.85it/s]
# Generating problems for 1813: 100%|██████████| 9/9 [00:00<00:00, 2025.15it/s]
# Generating problems for 1814: 100%|██████████| 9/9 [00:00<00:00, 2262.98it/s]
# Generating problems for 1815: 100%|██████████| 9/9 [00:00<00:00, 2025.58it/s]
# Generating problems for 1816: 100%|██████████| 10/10 [00:00<00:00, 2096.63it/s]
# Generating problems for 1817: 100%|██████████| 10/10 [00:00<00:00, 1408.81it/s]
# Generating problems for 1818: 100%|██████████| 10/10 [00:00<00:00, 1888.82it/s]
# Generating problems for 1819: 100%|██████████| 9/9 [00:00<00:00, 1721.96it/s]
# Generating problems for 1820: 100%|██████████| 9/9 [00:00<00:00, 1956.81it/s]
# Generating problems for 1821: 100%|██████████| 9/9 [00:00<00:00, 1937.22it/s]
# Generating problems for 1822: 100%|██████████| 9/9 [00:00<00:00, 2334.78it/s]
# Generating problems for 1823: 100%|██████████| 9/9 [00:00<00:00, 2050.00it/s]
# Generating problems for 1824: 100%|██████████| 9/9 [00:00<00:00, 2047.89it/s]
# Generating problems for 1825: 100%|██████████| 9/9 [00:00<00:00, 1911.62it/s]
# Generating problems for 1826: 100%|██████████| 6/6 [00:00<00:00, 1280.31it/s]
# Generating problems for 1827: 100%|██████████| 6/6 [00:00<00:00, 1791.80it/s]
# Generating problems for 1828: 100%|██████████| 6/6 [00:00<00:00, 1859.31it/s]
# Generating problems for 1829: 100%|██████████| 9/9 [00:00<00:00, 887.16it/s]
# Generating problems for 1830: 100%|██████████| 9/9 [00:00<00:00, 1315.88it/s]
# Generating problems for 1831: 100%|██████████| 7/7 [00:00<00:00, 1867.81it/s]
# Generating problems for 1832: 100%|██████████| 7/7 [00:00<00:00, 2011.52it/s]
# Generating problems for 1833: 100%|██████████| 10/10 [00:00<00:00, 2243.30it/s]
# Generating problems for 1834: 100%|██████████| 10/10 [00:00<00:00, 2598.06it/s]
# Generating problems for 1835: 100%|██████████| 10/10 [00:00<00:00, 1636.99it/s]
# Generating problems for 1836: 100%|██████████| 10/10 [00:00<00:00, 2029.27it/s]
# Generating problems for 1837: 100%|██████████| 10/10 [00:00<00:00, 1968.88it/s]
# Generating problems for 1838: 100%|██████████| 10/10 [00:00<00:00, 1327.73it/s]
# Generating problems for 1839: 100%|██████████| 10/10 [00:00<00:00, 1703.69it/s]
# Generating problems for 1840: 100%|██████████| 9/9 [00:00<00:00, 2521.96it/s]
# Generating problems for 1841: 100%|██████████| 9/9 [00:00<00:00, 2184.66it/s]
# Generating problems for 1842: 100%|██████████| 10/10 [00:00<00:00, 2337.70it/s]
# Generating problems for 1843: 100%|██████████| 10/10 [00:00<00:00, 2116.84it/s]
# Generating problems for 1844: 100%|██████████| 10/10 [00:00<00:00, 1277.35it/s]
# Generating problems for 1845: 100%|██████████| 10/10 [00:00<00:00, 2446.94it/s]
# Generating problems for 1846: 100%|██████████| 10/10 [00:00<00:00, 2295.48it/s]
# Generating problems for 1847: 100%|██████████| 10/10 [00:00<00:00, 1988.76it/s]
# Generating problems for 1848: 100%|██████████| 10/10 [00:00<00:00, 1920.91it/s]
# sftc_trn generated: 1849 total questions: 10430
# sftc_trn after highlighting: 10430

# %%
copyfile(data_dir + "RACE-H/sftc_RACE-H_v1_dev.jsonl", data_dir + "RACE-H/sftc_RACE-H_v1_tst.jsonl")
# Out:
# '/content/drive/MyDrive/NLU/Final Project/NLU_FinalProject/Data/JSONL_Formatted/RACE-H/sftc_RACE-H_v1_tst.jsonl'

# %%
cloze_data2 = ["SAT_ACT/SATACT_v3_trn.jsonl", "SAT_ACT/SATACT_v3_dev.jsonl"]
cloze_split = ["sftc_trn", "sftc_dev"]

for n in range(len(cloze_data2)):
  fn = cloze_split[n]
  dn = cloze_data2[n]
  output = []
  data = read_contexts(dn)

  for i, context in enumerate(data):
    output.append(problem_gen(context, str(i)))

  print(fn, "generated:", len(output), "total questions:", sum(len(item[1]) for item in output))

  output = hltag(output)

  print(fn, "after highlighting:", len(output))

  with open(data_dir + dn + '_' + fn, "w") as f:
    json.dump(output, f, indent=2)
# Out:
# sftc_trn generated: 919 total questions: 1075
# sftc_trn after highlighting: 1075
# sftc_dev generated: 131 total questions: 161
# sftc_dev after highlighting: 161

# %%
copyfile(data_dir + "SAT_ACT/sftc2_SATACT_v3_dev.jsonl", data_dir + "SAT_ACT/sftc2_SATACT_v3_tst.jsonl")
# Out:
# '/content/drive/MyDrive/NLU/Final Project/NLU_FinalProject/Data/JSONL_Formatted/SAT_ACT/sftc2_SATACT_v3_tst.jsonl'
